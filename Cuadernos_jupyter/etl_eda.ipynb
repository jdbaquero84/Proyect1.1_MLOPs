# %%
import re # La utilizo para realizar búsquedas y manipulaciones avanzadas de patrones de texto
import chardet # La utilizamos para detectar la codificación de caracteres en texto
import ast # La utilizo para analizar y manipular expresiones y declaraciones
import json #  La utilizo para trabajar con datos en formato JSON 
import pandas as pd

# %% [markdown]
# Dateccion de codificacion del archivo

# %%
def detectar_encoding(archivo):
    with open(archivo, 'rb') as f:
        resultado=chardet.detect(f.read())
        encoding= resultado['encoding']
        confianza=resultado['confidence']
        return (f'El encoding detectado es {encoding} con una confianza de {confianza*100:.2f}%')

# %% [markdown]
# AUSTRALIAN_USER_REVIEWS

# %%
archivo='australian_user_reviews.json'
detectar_encoding(archivo)
# Out:
# 'El encoding detectado es MacRoman con una confianza de 69.75%'

# %% [markdown]
# Ahora se itera el archivo para construir un dataframe.

# %%
rows = []
with open ('australian_user_reviews.json', encoding='MacRoman') as f:
    for line in f.readlines():
        rows.append(ast.literal_eval(line))

df_reviews = pd.DataFrame(rows)
df_reviews.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                                              reviews
# 0  [{'funny': '', 'posted': 'Posted November 5, 2...
# 1  [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2  [{'funny': '', 'posted': 'Posted February 3.',...
# 3  [{'funny': '', 'posted': 'Posted October 14, 2...
# 4  [{'funny': '3 people found this review funny',...

# %%
df_reviews.shape
# Out:
# (25799, 3)

# %% [markdown]
# Se define funcion para detectar columnas anidadas

# %%
def anidada_True(df):
    anidadas=[]
    for columna in df.columns:
        if df[columna].apply(lambda x: isinstance(x,(list,dict))).any():
            anidadas.append(columna)
    return (f'La/s columna/s con datos anidados es/son: {anidadas}')

# %%
anidada_True(df_reviews)
# Out:
# "La/s columna/s con datos anidados es/son: ['reviews']"

# %% [markdown]
# Como la columna anidada contiene diccionarios:

# %%
df_reviews['reviews']=df_reviews['reviews'].apply(lambda x: x[0] if isinstance(x, list) and len(x)>0 else {})

# %%
reviews_desanidado=df_reviews.join(pd.json_normalize(df_reviews['reviews']))

# %%
reviews_desanidado.head(2)
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
#
#                                              reviews funny  \
# 0  {'funny': '', 'posted': 'Posted November 5, 20...
# 1  {'funny': '', 'posted': 'Posted June 24, 2014....
#
#                      posted last_edited item_id  \
# 0  Posted November 5, 2011.                1250
# 1     Posted June 24, 2014.              251610
#
#                                            helpful recommend  \
# 0                                   No ratings yet      True
# 1  15 of 20 people (75%) found this review helpful      True
#
#                                               review
# 0  Simple yet with great replayability. In my opi...
# 1  I know what you think when you see this title ...

# %% [markdown]
# Se elimina la columna reviews

# %%
reviews_desanidado=reviews_desanidado.drop(columns=['reviews'], axis=1)

# %%
reviews_desanidado.head(3)
# Out:
#              user_id                                           user_url funny  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
#
#                      posted last_edited item_id  \
# 0  Posted November 5, 2011.                1250
# 1     Posted June 24, 2014.              251610
# 2        Posted February 3.              248820
#
#                                            helpful recommend  \
# 0                                   No ratings yet      True
# 1  15 of 20 people (75%) found this review helpful      True
# 2                                   No ratings yet      True
#
#                                               review
# 0  Simple yet with great replayability. In my opi...
# 1  I know what you think when you see this title ...
# 2  A suitably punishing roguelike platformer.  Wi...

# %%
reviews_desanidado.tail(3)
# Out:
#                  user_id                                           user_url  \
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                   funny           posted last_edited item_id  \
# 25796  1 person found this review funny  Posted June 23.                 570
# 25797                                    Posted July 21.              233270
# 25798  1 person found this review funny   Posted July 3.              273110
#
#                                               helpful recommend  \
# 25796  1 of 1 people (100%) found this review helpful      True
# 25797                                  No ratings yet      True
# 25798   1 of 2 people (50%) found this review helpful      True
#
#                                                   review
# 25796                                          Well Done
# 25797  this is a very fun and nice 80s themed shooter...
# 25798  had so much fun plaing this and collecting res...

# %%
reviews_desanidado['funny']

# %%
reviews_desanidado.shape
# Out:
# (25799, 9)

# %%
item=reviews_desanidado['item_id'].dropna()

# %%
reviews_desanidado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25799 entries, 0 to 25798
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      25799 non-null  object
#  1   user_url     25799 non-null  object
#  2   funny        25771 non-null  object
#  3   posted       25771 non-null  object
#  4   last_edited  25771 non-null  object
#  5   item_id      25771 non-null  object
#  6   helpful      25771 non-null  object
#  7   recommend    25771 non-null  object
#  8   review       25771 non-null  object
# dtypes: object(9)
# memory usage: 1.8+ MB

# %% [markdown]
# Se guarda la primera base de datos desanidad en un csv

# %%
reviews_desanidado.to_csv('aus_reviews.csv', index=False)

# %%
print(reviews_desanidado.isna().sum())
# Out:
# user_id         0
# user_url        0
# funny          28
# posted         28
# last_edited    28
# item_id        28
# helpful        28
# recommend      28
# review         28
# dtype: int64

# %%
print(reviews_desanidado.isnull().sum())
# Out:
# user_id         0
# user_url        0
# funny          28
# posted         28
# last_edited    28
# item_id        28
# helpful        28
# recommend      28
# review         28
# dtype: int64

# %% [markdown]
# Se re-confirma que los 28 datos faltantes sean correspondientes en termonios de las observaciones (filas)

# %%
reviews_filtrado=reviews_desanidado[reviews_desanidado['funny'].isna()]

# %%
reviews_filtrado
# Out:
#                  user_id                                           user_url  \
# 62                 gdxsd                 http://steamcommunity.com/id/gdxsd
# 83     76561198094224872  http://steamcommunity.com/profiles/76561198094...
# 1047   76561198021575394  http://steamcommunity.com/profiles/76561198021...
# 3954             cmuir37               http://steamcommunity.com/id/cmuir37
# 5394           Jaysteeny             http://steamcommunity.com/id/Jaysteeny
# 6135              ML8989                http://steamcommunity.com/id/ML8989
# 7583   76561198079215291  http://steamcommunity.com/profiles/76561198079...
# 7952   76561198079342142  http://steamcommunity.com/profiles/76561198079...
# 9894   76561198061996985  http://steamcommunity.com/profiles/76561198061...
# 10381  76561198108286351  http://steamcommunity.com/profiles/76561198108...
# 10560     CallTripleZero        http://steamcommunity.com/id/CallTripleZero
# 11316       Priceless612          http://steamcommunity.com/id/Priceless612
# 11320      diabolical666         http://steamcommunity.com/id/diabolical666
# 11549         DrScottnik            http://steamcommunity.com/id/DrScottnik
# 12865  76561198110176420  http://steamcommunity.com/profiles/76561198110...
# 13242         jojoPL1987            http://steamcommunity.com/id/jojoPL1987
# 13698        Kylee_Kylie           http://steamcommunity.com/id/Kylee_Kylie
# 15949             _samie                http://steamcommunity.com/id/_samie
# 15990   FifthExclamation      http://steamcommunity.com/id/FifthExclamation
# 16013             sbenji                http://steamcommunity.com/id/sbenji
# 16546     SpatialWheel14        http://steamcommunity.com/id/SpatialWheel14
# 17022  76561198065238937  http://steamcommunity.com/profiles/76561198065...
# 18201  76561198071075080  http://steamcommunity.com/profiles/76561198071...
# 21386  76561198063489150  http://steamcommunity.com/profiles/76561198063...
# 22705   thecommunistbear      http://steamcommunity.com/id/thecommunistbear
# 23785  76561198085883839  http://steamcommunity.com/profiles/76561198085...
# 24911  76561198100396147  http://steamcommunity.com/profiles/76561198100...
# 25001  76561198102423654  http://steamcommunity.com/profiles/76561198102...
#
#       funny posted last_edited item_id helpful recommend review
# 62      NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 83      NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 1047    NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 3954    NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 5394    NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 6135    NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 7583    NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 7952    NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 9894    NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 10381   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 10560   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 11316   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 11320   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 11549   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 12865   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 13242   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 13698   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 15949   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 15990   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 16013   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 16546   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 17022   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 18201   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 21386   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 22705   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 23785   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 24911   NaN    NaN         NaN     NaN     NaN       NaN    NaN
# 25001   NaN    NaN         NaN     NaN     NaN       NaN    NaN

# %% [markdown]
# las filas con valores nuleos son 28 lo que representa el 0.1%, por ende se descartan estas 28 observaciones

# %%
reviews_desanidado_nona=reviews_desanidado.dropna()

# %%
reviews_desanidado_nona.shape
# Out:
# (25771, 9)

# %%
reviews_desanidado_nona['funny']=reviews_desanidado_nona['funny'].replace('','0')

# %%
reviews_desanidado_nona.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#    funny                                          helpful recommend  \
# 0      0                                   No ratings yet      True
# 1      0  15 of 20 people (75%) found this review helpful      True
# 2      0                                   No ratings yet      True
# 3      0   2 of 2 people (100%) found this review helpful      True
# 4      3  35 of 43 people (81%) found this review helpful      True
#
#                                               review
# 0  Simple yet with great replayability. In my opi...
# 1  I know what you think when you see this title ...
# 2  A suitably punishing roguelike platformer.  Wi...
# 3  This game... is so fun. The fight sequences ha...
# 4                                            Git gud

# %%
reviews_desanidado_nona['funny'].unique()
# Out:
# array(['0', '3', '1', '5', '17', '2', '524', '4', '12', '6', '103', '16',
#        '34', '7', '9', '45', '207', '718', '23', '100', '11', '19', '32',
#        '44', '10', '20', '36', '15', '131', '279', '122', '269', '296',
#        '46', '8', '42', '80', '28', '417', '13', '14', '133', '115', '72',
#        '260', '405', '47', '1130', '856', '71', '30', '89', '75', '518',
#        '719', '82', '49', '167', '77', '60', '26', '675', '22', '99',
#        '120', '211', '27', '21', '228', '25', '76', '56', '85', '40',
#        '203', '480', '39', '759', '53', '38', '52', '70', '429', '18',
#        '69', '24', '41', '194', '124', '450', '607', '946', '50', '142',
#        '181', '171', '267', '139', '161', '1284', '127', '155', '191',
#        '51', '461', '94', '841', '2598', '57', '180', '502', '215', '830',
#        '327', '185', '255', '469', '1002', '198', '31', '214', '116',
#        '534', '33', '354', '128', '396', '59', '67', '162', '37', '284',
#        '1954', '276', '35', '29', '651', '83', '104', '1100', '150',
#        '126', '956', '264', '486', '43', '326', '210', '144', '92', '425',
#        '118', '491', '66', '88', '388', '196', '48', '135', '151', '2447',
#        '178', '876', '852', '233', '680', '172', '182', '86', '825'],
#       dtype=object)

# %% [markdown]
# Se retira, el texto, las celdas sin registro se cambian a cero, se retiran las comas y se convierte a tipo entero como la cantidad que encontraron divertido el comentario-

# %%
reviews_desanidado_nona.loc[reviews_desanidado_nona['funny'].str.contains(' people found this review funny', case=False), 'funny']=reviews_desanidado_nona['funny'].str.replace(' people found this review funny','', case=False)

# %%
reviews_desanidado_nona.loc[reviews_desanidado_nona['funny'].str.contains(' person found this review funny', case=False), 'funny']=reviews_desanidado_nona['funny'].str.replace(' person found this review funny','', case=False)

# %%
reviews_desanidado_nona.loc[reviews_desanidado_nona['funny'].str.contains(',', case=False), 'funny']=reviews_desanidado_nona['funny'].str.replace(',','', case=False)

# %%
funny=reviews_desanidado_nona['funny'].astype(int)

# %%
reviews_desanidado_nona['funny']=funny
# Out:
# C:\Users\57319\AppData\Local\Temp\ipykernel_13852\712542829.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews_desanidado_nona['funny']=funny

# %%
funny.sum()
# Out:
# 60061

# %% [markdown]
# se retiran las colunas que no se utilizaran para las consultas

# %%
reviews_desanidado_nona=reviews_desanidado_nona.drop(columns=['posted','last_edited','user_url'])

# %% [markdown]
# Ahora se analiza 'helpful' referente a que tan util fue la opinion

# %%
reviews_desanidado_nona['helpful'].unique()
# Out:
# array(['No ratings yet',
#        '15 of 20 people (75%) found this review helpful',
#        '2 of 2 people (100%) found this review helpful',
#        '35 of 43 people (81%) found this review helpful',
#        '7 of 8 people (88%) found this review helpful',
#        '0 of 1 people (0%) found this review helpful',
#        '3 of 3 people (100%) found this review helpful',
#        '0 of 2 people (0%) found this review helpful',
#        '2 of 4 people (50%) found this review helpful',
#        '1 of 3 people (33%) found this review helpful',
#        '28 of 31 people (90%) found this review helpful',
#        '6 of 9 people (67%) found this review helpful',
#        '1 of 2 people (50%) found this review helpful',
#        '3 of 5 people (60%) found this review helpful',
#        '4 of 5 people (80%) found this review helpful',
#        '0 of 8 people (0%) found this review helpful',
#        '27 of 41 people (66%) found this review helpful',
#        '1 of 1 people (100%) found this review helpful',
#        '4 of 4 people (100%) found this review helpful',
#        '3 of 6 people (50%) found this review helpful',
#        '0 of 11 people (0%) found this review helpful',
#        '2 of 3 people (67%) found this review helpful',
#        '1 of 5 people (20%) found this review helpful',
#        '3 of 4 people (75%) found this review helpful',
#        '194 of 282 people (69%) found this review helpful',
#        '424 of 470 people (90%) found this review helpful',
#        '28 of 41 people (68%) found this review helpful',
#        '97 of 102 people (95%) found this review helpful',
#        '2 of 7 people (29%) found this review helpful',
#        '4 of 6 people (67%) found this review helpful',
#        '3 of 8 people (38%) found this review helpful',
#        '2 of 12 people (17%) found this review helpful',
#        '6 of 10 people (60%) found this review helpful',
#        '7 of 17 people (41%) found this review helpful',
#        '16 of 48 people (33%) found this review helpful',
#        '9 of 12 people (75%) found this review helpful',
#        '3 of 7 people (43%) found this review helpful',
#        '9 of 10 people (90%) found this review helpful',
#        '14 of 19 people (74%) found this review helpful',
#        '20 of 23 people (87%) found this review helpful',
#        '5 of 8 people (63%) found this review helpful',
#        '131 of 188 people (70%) found this review helpful',
#        '2 of 6 people (33%) found this review helpful',
#        '6 of 8 people (75%) found this review helpful',
#        '13 of 15 people (87%) found this review helpful',
#        '95 of 173 people (55%) found this review helpful',
#        '52 of 62 people (84%) found this review helpful',
#        '0 of 3 people (0%) found this review helpful',
#        '16 of 20 people (80%) found this review helpful',
#        '15 of 27 people (56%) found this review helpful',
#        '11 of 19 people (58%) found this review helpful',
#        '2 of 5 people (40%) found this review helpful',
#        '4 of 23 people (17%) found this review helpful',
#        '12 of 14 people (86%) found this review helpful',
#        '20 of 29 people (69%) found this review helpful',
#        '26 of 33 people (79%) found this review helpful',
#        '108 of 147 people (73%) found this review helpful',
#        '6 of 6 people (100%) found this review helpful',
#        '1 of 4 people (25%) found this review helpful',
#        '4 of 12 people (33%) found this review helpful',
#        '11 of 14 people (79%) found this review helpful',
#        '77 of 122 people (63%) found this review helpful',
#        '177 of 221 people (80%) found this review helpful',
#        '4 of 7 people (57%) found this review helpful',
#        '7 of 7 people (100%) found this review helpful',
#        '13 of 28 people (46%) found this review helpful',
#        '1 of 6 people (17%) found this review helpful',
#        '9 of 15 people (60%) found this review helpful',
#        '10 of 16 people (63%) found this review helpful',
#        '5 of 5 people (100%) found this review helpful',
#        '17 of 23 people (74%) found this review helpful',
#        '17 of 36 people (47%) found this review helpful',
#        '41 of 51 people (80%) found this review helpful',
#        '6 of 11 people (55%) found this review helpful',
#        '126 of 214 people (59%) found this review helpful',
#        '8 of 8 people (100%) found this review helpful',
#        '5 of 7 people (71%) found this review helpful',
#        '5 of 13 people (38%) found this review helpful',
#        '18 of 27 people (67%) found this review helpful',
#        '512 of 630 people (81%) found this review helpful',
#        '31 of 36 people (86%) found this review helpful',
#        '8 of 9 people (89%) found this review helpful',
#        '0 of 4 people (0%) found this review helpful',
#        '64 of 67 people (96%) found this review helpful',
#        '376 of 413 people (91%) found this review helpful',
#        '5 of 11 people (45%) found this review helpful',
#        '9 of 16 people (56%) found this review helpful',
#        '9 of 11 people (82%) found this review helpful',
#        '224 of 365 people (61%) found this review helpful',
#        '5 of 6 people (83%) found this review helpful',
#        '7 of 9 people (78%) found this review helpful',
#        '7 of 14 people (50%) found this review helpful',
#        '8 of 10 people (80%) found this review helpful',
#        '18 of 25 people (72%) found this review helpful',
#        '27 of 52 people (52%) found this review helpful',
#        '1 of 8 people (13%) found this review helpful',
#        '11 of 17 people (65%) found this review helpful',
#        '10 of 10 people (100%) found this review helpful',
#        '13 of 13 people (100%) found this review helpful',
#        '42 of 55 people (76%) found this review helpful',
#        '14 of 24 people (58%) found this review helpful',
#        '6 of 7 people (86%) found this review helpful',
#        '0 of 5 people (0%) found this review helpful',
#        '20 of 21 people (95%) found this review helpful',
#        '1 of 12 people (8%) found this review helpful',
#        '15 of 24 people (63%) found this review helpful',
#        '2 of 16 people (13%) found this review helpful',
#        '54 of 61 people (89%) found this review helpful',
#        '83 of 106 people (78%) found this review helpful',
#        '691 of 848 people (81%) found this review helpful',
#        '38 of 42 people (90%) found this review helpful',
#        '7 of 10 people (70%) found this review helpful',
#        '30 of 49 people (61%) found this review helpful',
#        '18 of 22 people (82%) found this review helpful',
#        '0 of 14 people (0%) found this review helpful',
#        '9 of 9 people (100%) found this review helpful',
#        '26 of 31 people (84%) found this review helpful',
#        '11 of 99 people (11%) found this review helpful',
#        '1 of 7 people (14%) found this review helpful',
#        '7 of 13 people (54%) found this review helpful',
#        '8 of 11 people (73%) found this review helpful',
#        '42 of 60 people (70%) found this review helpful',
#        '8 of 13 people (62%) found this review helpful',
#        '18 of 62 people (29%) found this review helpful',
#        '43 of 43 people (100%) found this review helpful',
#        '65 of 115 people (57%) found this review helpful',
#        '1 of 9 people (11%) found this review helpful',
#        '4 of 10 people (40%) found this review helpful',
#        '24 of 38 people (63%) found this review helpful',
#        '5 of 10 people (50%) found this review helpful',
#        '25 of 26 people (96%) found this review helpful',
#        '64 of 75 people (85%) found this review helpful',
#        '18 of 33 people (55%) found this review helpful',
#        '87 of 135 people (64%) found this review helpful',
#        '15 of 19 people (79%) found this review helpful',
#        '26 of 29 people (90%) found this review helpful',
#        '0 of 27 people (0%) found this review helpful',
#        '107 of 164 people (65%) found this review helpful',
#        '0 of 13 people (0%) found this review helpful',
#        '0 of 9 people (0%) found this review helpful',
#        '112 of 206 people (54%) found this review helpful',
#        '55 of 83 people (66%) found this review helpful',
#        '38 of 47 people (81%) found this review helpful',
#        '5 of 9 people (56%) found this review helpful',
#        '8 of 12 people (67%) found this review helpful',
#        '14 of 21 people (67%) found this review helpful',
#        '81 of 102 people (79%) found this review helpful',
#        '3 of 12 people (25%) found this review helpful',
#        '229 of 349 people (66%) found this review helpful',
#        '3 of 9 people (33%) found this review helpful',
#        '3 of 14 people (21%) found this review helpful',
#        '12 of 15 people (80%) found this review helpful',
#        '20 of 32 people (63%) found this review helpful',
#        '9 of 13 people (69%) found this review helpful',
#        '10 of 12 people (83%) found this review helpful',
#        '114 of 127 people (90%) found this review helpful',
#        '33 of 35 people (94%) found this review helpful',
#        '17 of 20 people (85%) found this review helpful',
#        '17 of 31 people (55%) found this review helpful',
#        '15 of 21 people (71%) found this review helpful',
#        '1 of 22 people (5%) found this review helpful',
#        '11 of 11 people (100%) found this review helpful',
#        '3 of 10 people (30%) found this review helpful',
#        '17 of 26 people (65%) found this review helpful',
#        '6 of 12 people (50%) found this review helpful',
#        '11 of 24 people (46%) found this review helpful',
#        '38 of 55 people (69%) found this review helpful',
#        '10 of 13 people (77%) found this review helpful',
#        '80 of 93 people (86%) found this review helpful',
#        '235 of 304 people (77%) found this review helpful',
#        '386 of 415 people (93%) found this review helpful',
#        '6 of 24 people (25%) found this review helpful',
#        '4 of 8 people (50%) found this review helpful',
#        '3 of 11 people (27%) found this review helpful',
#        '10 of 14 people (71%) found this review helpful',
#        '11 of 18 people (61%) found this review helpful',
#        '45 of 56 people (80%) found this review helpful',
#        '27 of 50 people (54%) found this review helpful',
#        '12 of 12 people (100%) found this review helpful',
#        '9 of 14 people (64%) found this review helpful',
#        '61 of 102 people (60%) found this review helpful',
#        '118 of 142 people (83%) found this review helpful',
#        '16 of 16 people (100%) found this review helpful',
#        '14 of 78 people (18%) found this review helpful',
#        '21 of 35 people (60%) found this review helpful',
#        '2 of 13 people (15%) found this review helpful',
#        '575 of 771 people (75%) found this review helpful',
#        '86 of 99 people (87%) found this review helpful',
#        '23 of 29 people (79%) found this review helpful',
#        '33 of 36 people (92%) found this review helpful',
#        '22 of 25 people (88%) found this review helpful',
#        '63 of 78 people (81%) found this review helpful',
#        '87 of 103 people (84%) found this review helpful',
#        '14 of 23 people (61%) found this review helpful',
#        '314 of 373 people (84%) found this review helpful',
#        '54 of 83 people (65%) found this review helpful',
#        '12 of 19 people (63%) found this review helpful',
#        '123 of 128 people (96%) found this review helpful',
#        '12 of 16 people (75%) found this review helpful',
#        '19 of 228 people (8%) found this review helpful',
#        '2 of 10 people (20%) found this review helpful',
#        '22 of 24 people (92%) found this review helpful',
#        '149 of 207 people (72%) found this review helpful',
#        '7 of 11 people (64%) found this review helpful',
#        '15 of 23 people (65%) found this review helpful',
#        '2 of 11 people (18%) found this review helpful',
#        '4 of 9 people (44%) found this review helpful',
#        '8 of 16 people (50%) found this review helpful',
#        '3 of 13 people (23%) found this review helpful',
#        '43 of 48 people (90%) found this review helpful',
#        '122 of 184 people (66%) found this review helpful',
#        '6 of 21 people (29%) found this review helpful',
#        '1 of 14 people (7%) found this review helpful',
#        '143 of 154 people (93%) found this review helpful',
#        '268 of 288 people (93%) found this review helpful',
#        '17 of 22 people (77%) found this review helpful',
#        '13 of 17 people (76%) found this review helpful',
#        '567 of 755 people (75%) found this review helpful',
#        '14 of 17 people (82%) found this review helpful',
#        '1 of 10 people (10%) found this review helpful',
#        '27 of 33 people (82%) found this review helpful',
#        '17 of 24 people (71%) found this review helpful',
#        '22 of 23 people (96%) found this review helpful',
#        '173 of 238 people (73%) found this review helpful',
#        '25 of 34 people (74%) found this review helpful',
#        '7 of 25 people (28%) found this review helpful',
#        '8 of 17 people (47%) found this review helpful',
#        '10 of 11 people (91%) found this review helpful',
#        '1 of 27 people (4%) found this review helpful',
#        '43 of 59 people (73%) found this review helpful',
#        '20 of 28 people (71%) found this review helpful',
#        '27 of 28 people (96%) found this review helpful',
#        '11 of 12 people (92%) found this review helpful',
#        '13 of 26 people (50%) found this review helpful',
#        '55 of 75 people (73%) found this review helpful',
#        '4 of 15 people (27%) found this review helpful',
#        '51 of 63 people (81%) found this review helpful',
#        '8 of 20 people (40%) found this review helpful',
#        '18 of 20 people (90%) found this review helpful',
#        '0 of 7 people (0%) found this review helpful',
#        '16 of 34 people (47%) found this review helpful',
#        '2 of 33 people (6%) found this review helpful',
#        '462 of 522 people (89%) found this review helpful',
#        '11 of 30 people (37%) found this review helpful',
#        '248 of 391 people (63%) found this review helpful',
#        '0 of 10 people (0%) found this review helpful',
#        '1,594 of 1,739 people (92%) found this review helpful',
#        '793 of 941 people (84%) found this review helpful',
#        '48 of 57 people (84%) found this review helpful',
#        '973 of 1,099 people (89%) found this review helpful',
#        '15 of 32 people (47%) found this review helpful',
#        '14 of 15 people (93%) found this review helpful',
#        '43 of 86 people (50%) found this review helpful',
#        '2 of 18 people (11%) found this review helpful',
#        '21 of 23 people (91%) found this review helpful',
#        '22 of 30 people (73%) found this review helpful',
#        '108 of 163 people (66%) found this review helpful',
#        '19 of 28 people (68%) found this review helpful',
#        '24 of 31 people (77%) found this review helpful',
#        '8 of 15 people (53%) found this review helpful',
#        '15 of 22 people (68%) found this review helpful',
#        '29 of 41 people (71%) found this review helpful',
#        '4 of 20 people (20%) found this review helpful',
#        '4 of 27 people (15%) found this review helpful',
#        '297 of 395 people (75%) found this review helpful',
#        '132 of 142 people (93%) found this review helpful',
#        '75 of 124 people (60%) found this review helpful',
#        '8 of 19 people (42%) found this review helpful',
#        '36 of 36 people (100%) found this review helpful',
#        '0 of 6 people (0%) found this review helpful',
#        '11 of 15 people (73%) found this review helpful',
#        '20 of 27 people (74%) found this review helpful',
#        '20 of 24 people (83%) found this review helpful',
#        '7 of 12 people (58%) found this review helpful',
#        '12 of 25 people (48%) found this review helpful',
#        '372 of 440 people (85%) found this review helpful',
#        '86 of 103 people (83%) found this review helpful',
#        '31 of 47 people (66%) found this review helpful',
#        '19 of 21 people (90%) found this review helpful',
#        '23 of 39 people (59%) found this review helpful',
#        '1,694 of 2,110 people (80%) found this review helpful',
#        '24 of 35 people (69%) found this review helpful',
#        '198 of 290 people (68%) found this review helpful',
#        '10 of 15 people (67%) found this review helpful',
#        '1 of 11 people (9%) found this review helpful',
#        '6 of 13 people (46%) found this review helpful',
#        '57 of 78 people (73%) found this review helpful',
#        '668 of 876 people (76%) found this review helpful',
#        '13 of 16 people (81%) found this review helpful',
#        '85 of 102 people (83%) found this review helpful',
#        '146 of 218 people (67%) found this review helpful',
#        '10 of 21 people (48%) found this review helpful',
#        '25 of 45 people (56%) found this review helpful',
#        '18 of 19 people (95%) found this review helpful',
#        '90 of 122 people (74%) found this review helpful',
#        '58 of 62 people (94%) found this review helpful',
#        '2 of 8 people (25%) found this review helpful',
#        '68 of 75 people (91%) found this review helpful',
#        '259 of 309 people (84%) found this review helpful',
#        '62 of 82 people (76%) found this review helpful',
#        '13 of 20 people (65%) found this review helpful',
#        '23 of 26 people (88%) found this review helpful',
#        '65 of 72 people (90%) found this review helpful',
#        '31 of 61 people (51%) found this review helpful',
#        '4 of 11 people (36%) found this review helpful',
#        '4 of 13 people (31%) found this review helpful',
#        '250 of 352 people (71%) found this review helpful',
#        '23 of 45 people (51%) found this review helpful',
#        '11 of 13 people (85%) found this review helpful',
#        '88 of 93 people (95%) found this review helpful',
#        '33 of 55 people (60%) found this review helpful',
#        '94 of 101 people (93%) found this review helpful',
#        '123 of 204 people (60%) found this review helpful',
#        '25 of 30 people (83%) found this review helpful',
#        '981 of 1,122 people (87%) found this review helpful',
#        '376 of 648 people (58%) found this review helpful',
#        '97 of 114 people (85%) found this review helpful',
#        '46 of 54 people (85%) found this review helpful',
#        '84 of 112 people (75%) found this review helpful',
#        '23 of 23 people (100%) found this review helpful',
#        '21 of 24 people (88%) found this review helpful',
#        '130 of 185 people (70%) found this review helpful',
#        '23 of 27 people (85%) found this review helpful',
#        '202 of 242 people (83%) found this review helpful',
#        '17 of 69 people (25%) found this review helpful',
#        '15 of 18 people (83%) found this review helpful',
#        '14 of 20 people (70%) found this review helpful',
#        '19 of 36 people (53%) found this review helpful',
#        '455 of 638 people (71%) found this review helpful',
#        '32 of 43 people (74%) found this review helpful',
#        '50 of 97 people (52%) found this review helpful',
#        '35 of 55 people (64%) found this review helpful',
#        '8 of 79 people (10%) found this review helpful',
#        '18 of 30 people (60%) found this review helpful',
#        '99 of 118 people (84%) found this review helpful',
#        '22 of 33 people (67%) found this review helpful',
#        '69 of 81 people (85%) found this review helpful',
#        '35 of 40 people (88%) found this review helpful',
#        '13 of 21 people (62%) found this review helpful',
#        '40 of 53 people (75%) found this review helpful',
#        '91 of 109 people (83%) found this review helpful',
#        '12 of 68 people (18%) found this review helpful',
#        '89 of 114 people (78%) found this review helpful',
#        '41 of 41 people (100%) found this review helpful',
#        '13 of 43 people (30%) found this review helpful',
#        '46 of 66 people (70%) found this review helpful',
#        '8 of 25 people (32%) found this review helpful',
#        '44 of 61 people (72%) found this review helpful',
#        '40 of 58 people (69%) found this review helpful',
#        '92 of 165 people (56%) found this review helpful',
#        '19 of 22 people (86%) found this review helpful',
#        '6 of 14 people (43%) found this review helpful',
#        '53 of 55 people (96%) found this review helpful',
#        '112 of 131 people (85%) found this review helpful',
#        '20 of 61 people (33%) found this review helpful',
#        '87 of 127 people (69%) found this review helpful',
#        '12 of 13 people (92%) found this review helpful',
#        '14 of 16 people (88%) found this review helpful',
#        '6 of 62 people (10%) found this review helpful',
#        '14 of 18 people (78%) found this review helpful',
#        '3 of 21 people (14%) found this review helpful',
#        '75 of 85 people (88%) found this review helpful',
#        '15 of 30 people (50%) found this review helpful',
#        '1 of 29 people (3%) found this review helpful',
#        '33 of 38 people (87%) found this review helpful',
#        '13 of 25 people (52%) found this review helpful',
#        '102 of 133 people (77%) found this review helpful',
#        '59 of 89 people (66%) found this review helpful',
#        '12 of 18 people (67%) found this review helpful',
#        '2 of 9 people (22%) found this review helpful',
#        '52 of 64 people (81%) found this review helpful',
#        '7 of 21 people (33%) found this review helpful',
#        '1 of 23 people (4%) found this review helpful',
#        '306 of 325 people (94%) found this review helpful',
#        '34 of 43 people (79%) found this review helpful',
#        '24 of 24 people (100%) found this review helpful',
#        '40 of 54 people (74%) found this review helpful',
#        '25 of 27 people (93%) found this review helpful',
#        '13 of 22 people (59%) found this review helpful',
#        '101 of 139 people (73%) found this review helpful',
#        '13 of 18 people (72%) found this review helpful',
#        '126 of 232 people (54%) found this review helpful',
#        '802 of 1,038 people (77%) found this review helpful',
#        '19 of 20 people (95%) found this review helpful',
#        '15 of 15 people (100%) found this review helpful',
#        '20 of 26 people (77%) found this review helpful',
#        '17 of 21 people (81%) found this review helpful',
#        '9 of 17 people (53%) found this review helpful',
#        '146 of 156 people (94%) found this review helpful',
#        '24 of 28 people (86%) found this review helpful',
#        '55 of 66 people (83%) found this review helpful',
#        '16 of 33 people (48%) found this review helpful',
#        '21 of 31 people (68%) found this review helpful',
#        '10 of 38 people (26%) found this review helpful',
#        '6 of 20 people (30%) found this review helpful',
#        '26 of 51 people (51%) found this review helpful',
#        '13 of 19 people (68%) found this review helpful',
#        '50 of 78 people (64%) found this review helpful',
#        '88 of 90 people (98%) found this review helpful',
#        '1 of 20 people (5%) found this review helpful',
#        '218 of 244 people (89%) found this review helpful',
#        '460 of 545 people (84%) found this review helpful',
#        '223 of 245 people (91%) found this review helpful',
#        '31 of 66 people (47%) found this review helpful',
#        '15 of 16 people (94%) found this review helpful',
#        '82 of 93 people (88%) found this review helpful',
#        '28 of 33 people (85%) found this review helpful',
#        '39 of 49 people (80%) found this review helpful',
#        '17 of 19 people (89%) found this review helpful',
#        '21 of 21 people (100%) found this review helpful',
#        '19 of 26 people (73%) found this review helpful',
#        '519 of 656 people (79%) found this review helpful',
#        '16 of 23 people (70%) found this review helpful',
#        '577 of 740 people (78%) found this review helpful',
#        '1,023 of 1,748 people (59%) found this review helpful',
#        '878 of 1,051 people (84%) found this review helpful',
#        '16 of 21 people (76%) found this review helpful',
#        '6 of 35 people (17%) found this review helpful',
#        '11 of 20 people (55%) found this review helpful',
#        '124 of 136 people (91%) found this review helpful',
#        '21 of 36 people (58%) found this review helpful',
#        '69 of 77 people (90%) found this review helpful',
#        '4 of 65 people (6%) found this review helpful',
#        '32 of 63 people (51%) found this review helpful',
#        '30 of 41 people (73%) found this review helpful',
#        '2 of 17 people (12%) found this review helpful',
#        '21 of 32 people (66%) found this review helpful',
#        '28 of 40 people (70%) found this review helpful',
#        '145 of 207 people (70%) found this review helpful',
#        '13 of 56 people (23%) found this review helpful',
#        '493 of 618 people (80%) found this review helpful',
#        '133 of 245 people (54%) found this review helpful',
#        '7 of 19 people (37%) found this review helpful',
#        '19 of 24 people (79%) found this review helpful',
#        '118 of 186 people (63%) found this review helpful',
#        '31 of 34 people (91%) found this review helpful',
#        '513 of 566 people (91%) found this review helpful',
#        '29 of 32 people (91%) found this review helpful',
#        '18 of 23 people (78%) found this review helpful',
#        '38 of 49 people (78%) found this review helpful',
#        '6 of 17 people (35%) found this review helpful',
#        '16 of 22 people (73%) found this review helpful',
#        '186 of 285 people (65%) found this review helpful',
#        '77 of 106 people (73%) found this review helpful',
#        '29 of 42 people (69%) found this review helpful',
#        '58 of 71 people (82%) found this review helpful',
#        '70 of 73 people (96%) found this review helpful',
#        '24 of 29 people (83%) found this review helpful',
#        '69 of 90 people (77%) found this review helpful',
#        '2 of 15 people (13%) found this review helpful',
#        '40 of 56 people (71%) found this review helpful',
#        '92 of 111 people (83%) found this review helpful',
#        '12 of 24 people (50%) found this review helpful',
#        '77 of 92 people (84%) found this review helpful',
#        '48 of 76 people (63%) found this review helpful',
#        '78 of 93 people (84%) found this review helpful',
#        '86 of 98 people (88%) found this review helpful',
#        '38 of 41 people (93%) found this review helpful',
#        '73 of 92 people (79%) found this review helpful',
#        '249 of 372 people (67%) found this review helpful',
#        '322 of 351 people (92%) found this review helpful',
#        '392 of 474 people (83%) found this review helpful',
#        '56 of 80 people (70%) found this review helpful',
#        '11 of 22 people (50%) found this review helpful',
#        '146 of 167 people (87%) found this review helpful',
#        '10 of 17 people (59%) found this review helpful',
#        '831 of 954 people (87%) found this review helpful',
#        '131 of 140 people (94%) found this review helpful',
#        '75 of 79 people (95%) found this review helpful',
#        '24 of 51 people (47%) found this review helpful',
#        '64 of 80 people (80%) found this review helpful',
#        '20 of 38 people (53%) found this review helpful',
#        '4 of 18 people (22%) found this review helpful',
#        '158 of 165 people (96%) found this review helpful',
#        '73 of 96 people (76%) found this review helpful',
#        '7 of 16 people (44%) found this review helpful',
#        '3 of 20 people (15%) found this review helpful',
#        '48 of 65 people (74%) found this review helpful',
#        '14 of 26 people (54%) found this review helpful',
#        '53 of 67 people (79%) found this review helpful',
#        '16 of 25 people (64%) found this review helpful',
#        '22 of 29 people (76%) found this review helpful',
#        '19 of 25 people (76%) found this review helpful',
#        '27 of 42 people (64%) found this review helpful',
#        '15 of 25 people (60%) found this review helpful',
#        '26 of 40 people (65%) found this review helpful',
#        '139 of 196 people (71%) found this review helpful',
#        '8 of 18 people (44%) found this review helpful',
#        '290 of 343 people (85%) found this review helpful',
#        '137 of 150 people (91%) found this review helpful',
#        '235 of 294 people (80%) found this review helpful',
#        '0 of 15 people (0%) found this review helpful',
#        '64 of 71 people (90%) found this review helpful',
#        '438 of 641 people (68%) found this review helpful',
#        '389 of 673 people (58%) found this review helpful',
#        '49 of 73 people (67%) found this review helpful',
#        '43 of 65 people (66%) found this review helpful',
#        '13 of 27 people (48%) found this review helpful',
#        '128 of 192 people (67%) found this review helpful',
#        '529 of 663 people (80%) found this review helpful',
#        '39 of 70 people (56%) found this review helpful',
#        '283 of 334 people (85%) found this review helpful',
#        '63 of 86 people (73%) found this review helpful',
#        '35 of 39 people (90%) found this review helpful',
#        '123 of 171 people (72%) found this review helpful',
#        '24 of 46 people (52%) found this review helpful',
#        '35 of 68 people (51%) found this review helpful',
#        '1,306 of 1,335 people (98%) found this review helpful',
#        '99 of 163 people (61%) found this review helpful',
#        '16 of 17 people (94%) found this review helpful',
#        '83 of 116 people (72%) found this review helpful',
#        '65 of 112 people (58%) found this review helpful',
#        '3 of 34 people (9%) found this review helpful',
#        '33 of 42 people (79%) found this review helpful',
#        '152 of 368 people (41%) found this review helpful',
#        '94 of 108 people (87%) found this review helpful',
#        '2 of 14 people (14%) found this review helpful',
#        '18 of 24 people (75%) found this review helpful',
#        '155 of 179 people (87%) found this review helpful',
#        '80 of 105 people (76%) found this review helpful',
#        '17 of 29 people (59%) found this review helpful',
#        '831 of 1,056 people (79%) found this review helpful',
#        '78 of 136 people (57%) found this review helpful',
#        '27 of 49 people (55%) found this review helpful',
#        '204 of 259 people (79%) found this review helpful',
#        '132 of 162 people (81%) found this review helpful',
#        '77 of 79 people (97%) found this review helpful',
#        '36 of 47 people (77%) found this review helpful',
#        '39 of 54 people (72%) found this review helpful',
#        '1 of 15 people (7%) found this review helpful',
#        '81 of 97 people (84%) found this review helpful',
#        '30 of 40 people (75%) found this review helpful',
#        '20 of 25 people (80%) found this review helpful',
#        '10 of 18 people (56%) found this review helpful',
#        '35 of 36 people (97%) found this review helpful',
#        '389 of 572 people (68%) found this review helpful',
#        '229 of 255 people (90%) found this review helpful',
#        '21 of 27 people (78%) found this review helpful',
#        '23 of 34 people (68%) found this review helpful',
#        '18 of 35 people (51%) found this review helpful',
#        '147 of 179 people (82%) found this review helpful',
#        '34 of 40 people (85%) found this review helpful',
#        '668 of 722 people (93%) found this review helpful',
#        '25 of 35 people (71%) found this review helpful',
#        '6 of 32 people (19%) found this review helpful',
#        '126 of 234 people (54%) found this review helpful',
#        '89 of 103 people (86%) found this review helpful',
#        '6 of 44 people (14%) found this review helpful',
#        '109 of 128 people (85%) found this review helpful',
#        '67 of 98 people (68%) found this review helpful',
#        '17 of 17 people (100%) found this review helpful',
#        '10 of 19 people (53%) found this review helpful',
#        '1 of 32 people (3%) found this review helpful',
#        '11 of 16 people (69%) found this review helpful',
#        '12 of 22 people (55%) found this review helpful',
#        '7 of 132 people (5%) found this review helpful',
#        '12 of 17 people (71%) found this review helpful',
#        '589 of 639 people (92%) found this review helpful',
#        '27 of 30 people (90%) found this review helpful',
#        '12 of 41 people (29%) found this review helpful',
#        '38 of 40 people (95%) found this review helpful',
#        '39 of 51 people (76%) found this review helpful',
#        '37 of 42 people (88%) found this review helpful',
#        '154 of 192 people (80%) found this review helpful',
#        '18 of 31 people (58%) found this review helpful',
#        '21 of 28 people (75%) found this review helpful',
#        '5 of 12 people (42%) found this review helpful',
#        '30 of 61 people (49%) found this review helpful',
#        '9 of 19 people (47%) found this review helpful',
#        '52 of 173 people (30%) found this review helpful',
#        '2,200 of 2,593 people (85%) found this review helpful',
#        '47 of 55 people (85%) found this review helpful',
#        '126 of 140 people (90%) found this review helpful',
#        '514 of 625 people (82%) found this review helpful',
#        '412 of 458 people (90%) found this review helpful',
#        '27 of 44 people (61%) found this review helpful',
#        '1 of 16 people (6%) found this review helpful',
#        '82 of 85 people (96%) found this review helpful',
#        '18 of 26 people (69%) found this review helpful',
#        '17 of 18 people (94%) found this review helpful',
#        '15 of 17 people (88%) found this review helpful',
#        '395 of 444 people (89%) found this review helpful',
#        '24 of 30 people (80%) found this review helpful',
#        '24 of 25 people (96%) found this review helpful',
#        '17 of 30 people (57%) found this review helpful',
#        '281 of 377 people (75%) found this review helpful',
#        '22 of 54 people (41%) found this review helpful',
#        '535 of 667 people (80%) found this review helpful',
#        '190 of 247 people (77%) found this review helpful',
#        '126 of 202 people (62%) found this review helpful',
#        '11 of 34 people (32%) found this review helpful',
#        '126 of 236 people (53%) found this review helpful',
#        '8 of 14 people (57%) found this review helpful',
#        '13 of 24 people (54%) found this review helpful',
#        '5 of 22 people (23%) found this review helpful',
#        '8 of 27 people (30%) found this review helpful',
#        '36 of 51 people (71%) found this review helpful',
#        '27 of 31 people (87%) found this review helpful',
#        '135 of 187 people (72%) found this review helpful',
#        '333 of 389 people (86%) found this review helpful',
#        '1 of 13 people (8%) found this review helpful',
#        '40 of 46 people (87%) found this review helpful',
#        '64 of 107 people (60%) found this review helpful',
#        '493 of 578 people (85%) found this review helpful',
#        '7 of 15 people (47%) found this review helpful',
#        '13 of 14 people (93%) found this review helpful',
#        '28 of 32 people (88%) found this review helpful',
#        '49 of 64 people (77%) found this review helpful',
#        '52 of 70 people (74%) found this review helpful',
#        '91 of 105 people (87%) found this review helpful',
#        '134 of 159 people (84%) found this review helpful',
#        '331 of 365 people (91%) found this review helpful',
#        '704 of 874 people (81%) found this review helpful',
#        '17 of 35 people (49%) found this review helpful',
#        '14 of 14 people (100%) found this review helpful',
#        '5 of 14 people (36%) found this review helpful',
#        '26 of 45 people (58%) found this review helpful',
#        '69 of 99 people (70%) found this review helpful',
#        '49 of 61 people (80%) found this review helpful',
#        '55 of 88 people (63%) found this review helpful',
#        '262 of 303 people (86%) found this review helpful',
#        '23 of 24 people (96%) found this review helpful',
#        '247 of 302 people (82%) found this review helpful',
#        '173 of 295 people (59%) found this review helpful',
#        '224 of 382 people (59%) found this review helpful',
#        '73 of 118 people (62%) found this review helpful',
#        '20 of 42 people (48%) found this review helpful',
#        '85 of 92 people (92%) found this review helpful',
#        '187 of 215 people (87%) found this review helpful',
#        '27 of 29 people (93%) found this review helpful',
#        '80 of 117 people (68%) found this review helpful',
#        '561 of 574 people (98%) found this review helpful',
#        '16 of 28 people (57%) found this review helpful',
#        '403 of 480 people (84%) found this review helpful',
#        '177 of 195 people (91%) found this review helpful',
#        '42 of 54 people (78%) found this review helpful',
#        '43 of 70 people (61%) found this review helpful',
#        '33 of 46 people (72%) found this review helpful',
#        '17 of 38 people (45%) found this review helpful',
#        '404 of 583 people (69%) found this review helpful',
#        '180 of 203 people (89%) found this review helpful',
#        '19 of 27 people (70%) found this review helpful',
#        '62 of 68 people (91%) found this review helpful',
#        '27 of 65 people (42%) found this review helpful',
#        '360 of 660 people (55%) found this review helpful',
#        '498 of 582 people (86%) found this review helpful',
#        '115 of 136 people (85%) found this review helpful',
#        '15 of 35 people (43%) found this review helpful',
#        '31 of 40 people (78%) found this review helpful',
#        '401 of 606 people (66%) found this review helpful',
#        '111 of 138 people (80%) found this review helpful',
#        '21 of 39 people (54%) found this review helpful',
#        '21 of 40 people (53%) found this review helpful',
#        '36 of 39 people (92%) found this review helpful',
#        '47 of 90 people (52%) found this review helpful',
#        '44 of 73 people (60%) found this review helpful',
#        '26 of 55 people (47%) found this review helpful',
#        '28 of 47 people (60%) found this review helpful',
#        '105 of 139 people (76%) found this review helpful',
#        '186 of 256 people (73%) found this review helpful',
#        '46 of 49 people (94%) found this review helpful',
#        '30 of 32 people (94%) found this review helpful',
#        '214 of 245 people (87%) found this review helpful',
#        '52 of 67 people (78%) found this review helpful',
#        '1,581 of 1,678 people (94%) found this review helpful',
#        '332 of 379 people (88%) found this review helpful',
#        '22 of 32 people (69%) found this review helpful',
#        '257 of 306 people (84%) found this review helpful',
#        '39 of 46 people (85%) found this review helpful',
#        '34 of 54 people (63%) found this review helpful',
#        '18 of 29 people (62%) found this review helpful',
#        '10 of 22 people (45%) found this review helpful',
#        '72 of 76 people (95%) found this review helpful',
#        '78 of 88 people (89%) found this review helpful',
#        '100 of 173 people (58%) found this review helpful',
#        '82 of 89 people (92%) found this review helpful',
#        '23 of 41 people (56%) found this review helpful',
#        '3 of 43 people (7%) found this review helpful',
#        '37 of 45 people (82%) found this review helpful',
#        '647 of 794 people (81%) found this review helpful',
#        '29 of 52 people (56%) found this review helpful',
#        '10 of 20 people (50%) found this review helpful',
#        '27 of 32 people (84%) found this review helpful',
#        '5 of 25 people (20%) found this review helpful',
#        '35 of 42 people (83%) found this review helpful',
#        '14 of 22 people (64%) found this review helpful',
#        '60 of 114 people (53%) found this review helpful',
#        '195 of 281 people (69%) found this review helpful',
#        '146 of 208 people (70%) found this review helpful',
#        '31 of 45 people (69%) found this review helpful',
#        '1,989 of 2,068 people (96%) found this review helpful',
#        '462 of 608 people (76%) found this review helpful',
#        '4 of 24 people (17%) found this review helpful',
#        '1,830 of 2,143 people (85%) found this review helpful',
#        '15 of 28 people (54%) found this review helpful',
#        '1 of 17 people (6%) found this review helpful',
#        '275 of 347 people (79%) found this review helpful',
#        '160 of 180 people (89%) found this review helpful',
#        '38 of 43 people (88%) found this review helpful',
#        '810 of 917 people (88%) found this review helpful',
#        '24 of 27 people (89%) found this review helpful',
#        '48 of 71 people (68%) found this review helpful',
#        '391 of 453 people (86%) found this review helpful',
#        '19 of 37 people (51%) found this review helpful',
#        '476 of 712 people (67%) found this review helpful',
#        '112 of 214 people (52%) found this review helpful',
#        '157 of 302 people (52%) found this review helpful',
#        '29 of 34 people (85%) found this review helpful',
#        '14 of 37 people (38%) found this review helpful',
#        '12 of 20 people (60%) found this review helpful',
#        '22 of 26 people (85%) found this review helpful',
#        '1,792 of 2,002 people (90%) found this review helpful',
#        '38 of 68 people (56%) found this review helpful',
#        '44 of 58 people (76%) found this review helpful',
#        '14 of 97 people (14%) found this review helpful',
#        '6 of 15 people (40%) found this review helpful',
#        '4 of 28 people (14%) found this review helpful',
#        '16 of 26 people (62%) found this review helpful',
#        '112 of 147 people (76%) found this review helpful',
#        '27 of 39 people (69%) found this review helpful',
#        '26 of 28 people (93%) found this review helpful',
#        '3 of 15 people (20%) found this review helpful',
#        '16 of 19 people (84%) found this review helpful',
#        '18 of 34 people (53%) found this review helpful',
#        '63 of 94 people (67%) found this review helpful',
#        '21 of 22 people (95%) found this review helpful',
#        '32 of 37 people (86%) found this review helpful',
#        '11 of 21 people (52%) found this review helpful',
#        '49 of 74 people (66%) found this review helpful',
#        '46 of 73 people (63%) found this review helpful',
#        '1,094 of 1,493 people (73%) found this review helpful',
#        '23 of 137 people (17%) found this review helpful',
#        '0 of 22 people (0%) found this review helpful',
#        '5 of 21 people (24%) found this review helpful',
#        '16 of 27 people (59%) found this review helpful',
#        '20 of 33 people (61%) found this review helpful',
#        '39 of 56 people (70%) found this review helpful',
#        '32 of 36 people (89%) found this review helpful',
#        '1,465 of 1,787 people (82%) found this review helpful',
#        '111 of 134 people (83%) found this review helpful',
#        '1,144 of 1,356 people (84%) found this review helpful',
#        '276 of 321 people (86%) found this review helpful',
#        '131 of 194 people (68%) found this review helpful',
#        '129 of 160 people (81%) found this review helpful',
#        '28 of 38 people (74%) found this review helpful',
#        '438 of 600 people (73%) found this review helpful',
#        '55 of 98 people (56%) found this review helpful',
#        '19 of 32 people (59%) found this review helpful',
#        '87 of 112 people (78%) found this review helpful',
#        '67 of 84 people (80%) found this review helpful',
#        '5 of 20 people (25%) found this review helpful',
#        '3 of 28 people (11%) found this review helpful',
#        '370 of 406 people (91%) found this review helpful',
#        '55 of 72 people (76%) found this review helpful',
#        '5 of 28 people (18%) found this review helpful',
#        '54 of 110 people (49%) found this review helpful',
#        '30 of 30 people (100%) found this review helpful',
#        '6 of 18 people (33%) found this review helpful',
#        '42 of 56 people (75%) found this review helpful',
#        '27 of 40 people (68%) found this review helpful',
#        '0 of 19 people (0%) found this review helpful',
#        '43 of 53 people (81%) found this review helpful',
#        '29 of 44 people (66%) found this review helpful',
#        '312 of 381 people (82%) found this review helpful',
#        '133 of 158 people (84%) found this review helpful',
#        '914 of 1,215 people (75%) found this review helpful',
#        '189 of 303 people (62%) found this review helpful',
#        '76 of 99 people (77%) found this review helpful',
#        '2,487 of 2,919 people (85%) found this review helpful',
#        '48 of 52 people (92%) found this review helpful',
#        '6 of 22 people (27%) found this review helpful',
#        '0 of 32 people (0%) found this review helpful',
#        '1 of 42 people (2%) found this review helpful',
#        '54 of 64 people (84%) found this review helpful',
#        '46 of 52 people (88%) found this review helpful',
#        '48 of 53 people (91%) found this review helpful',
#        '42 of 74 people (57%) found this review helpful',
#        '84 of 114 people (74%) found this review helpful',
#        '45 of 58 people (78%) found this review helpful',
#        '127 of 161 people (79%) found this review helpful',
#        '24 of 36 people (67%) found this review helpful',
#        '5 of 46 people (11%) found this review helpful',
#        '81 of 123 people (66%) found this review helpful',
#        '268 of 412 people (65%) found this review helpful',
#        '25 of 48 people (52%) found this review helpful',
#        '34 of 55 people (62%) found this review helpful',
#        '102 of 116 people (88%) found this review helpful',
#        '26 of 36 people (72%) found this review helpful',
#        '101 of 299 people (34%) found this review helpful',
#        '3 of 18 people (17%) found this review helpful',
#        '5 of 15 people (33%) found this review helpful',
#        '636 of 774 people (82%) found this review helpful',
#        '757 of 828 people (91%) found this review helpful',
#        '11 of 29 people (38%) found this review helpful',
#        '35 of 37 people (95%) found this review helpful',
#        '61 of 70 people (87%) found this review helpful',
#        '120 of 135 people (89%) found this review helpful',
#        '15 of 36 people (42%) found this review helpful',
#        '30 of 34 people (88%) found this review helpful',
#        '23 of 55 people (42%) found this review helpful',
#        '109 of 131 people (83%) found this review helpful',
#        '4 of 17 people (24%) found this review helpful',
#        '162 of 180 people (90%) found this review helpful',
#        '26 of 42 people (62%) found this review helpful',
#        '332 of 384 people (86%) found this review helpful',
#        '14 of 29 people (48%) found this review helpful',
#        '1 of 18 people (6%) found this review helpful',
#        '63 of 80 people (79%) found this review helpful',
#        '44 of 51 people (86%) found this review helpful',
#        '587 of 609 people (96%) found this review helpful',
#        '350 of 540 people (65%) found this review helpful',
#        '116 of 139 people (83%) found this review helpful',
#        '37 of 43 people (86%) found this review helpful',
#        '29 of 31 people (94%) found this review helpful',
#        '14 of 32 people (44%) found this review helpful',
#        '491 of 582 people (84%) found this review helpful',
#        '103 of 139 people (74%) found this review helpful',
#        '88 of 130 people (68%) found this review helpful',
#        '134 of 215 people (62%) found this review helpful',
#        '33 of 39 people (85%) found this review helpful',
#        '147 of 175 people (84%) found this review helpful',
#        '16 of 18 people (89%) found this review helpful',
#        '161 of 208 people (77%) found this review helpful',
#        '109 of 121 people (90%) found this review helpful',
#        '7 of 22 people (32%) found this review helpful',
#        '4 of 14 people (29%) found this review helpful',
#        '44 of 50 people (88%) found this review helpful',
#        '41 of 42 people (98%) found this review helpful',
#        '173 of 206 people (84%) found this review helpful',
#        '132 of 161 people (82%) found this review helpful',
#        '30 of 56 people (54%) found this review helpful',
#        '61 of 99 people (62%) found this review helpful',
#        '3 of 27 people (11%) found this review helpful',
#        '274 of 365 people (75%) found this review helpful',
#        '34 of 39 people (87%) found this review helpful',
#        '16 of 70 people (23%) found this review helpful',
#        '30 of 43 people (70%) found this review helpful',
#        '29 of 45 people (64%) found this review helpful',
#        '101 of 137 people (74%) found this review helpful',
#        '1,075 of 1,470 people (73%) found this review helpful',
#        '62 of 72 people (86%) found this review helpful',
#        '200 of 223 people (90%) found this review helpful',
#        '71 of 89 people (80%) found this review helpful',
#        '6 of 16 people (38%) found this review helpful',
#        '386 of 429 people (90%) found this review helpful',
#        '25 of 31 people (81%) found this review helpful',
#        '40 of 55 people (73%) found this review helpful',
#        '21 of 33 people (64%) found this review helpful',
#        '34 of 36 people (94%) found this review helpful',
#        '3 of 19 people (16%) found this review helpful',
#        '32 of 32 people (100%) found this review helpful',
#        '0 of 12 people (0%) found this review helpful',
#        '93 of 141 people (66%) found this review helpful',
#        '17 of 28 people (61%) found this review helpful',
#        '39 of 43 people (91%) found this review helpful',
#        '39 of 61 people (64%) found this review helpful',
#        '31 of 37 people (84%) found this review helpful',
#        '362 of 478 people (76%) found this review helpful',
#        '503 of 628 people (80%) found this review helpful',
#        '182 of 277 people (66%) found this review helpful',
#        '27 of 63 people (43%) found this review helpful',
#        '1,093 of 1,165 people (94%) found this review helpful',
#        '134 of 322 people (42%) found this review helpful',
#        '136 of 172 people (79%) found this review helpful',
#        '18 of 21 people (86%) found this review helpful',
#        '11 of 27 people (41%) found this review helpful',
#        '73 of 83 people (88%) found this review helpful',
#        '40 of 76 people (53%) found this review helpful',
#        '423 of 598 people (71%) found this review helpful',
#        '13 of 30 people (43%) found this review helpful',
#        '32 of 40 people (80%) found this review helpful',
#        '189 of 347 people (54%) found this review helpful',
#        '72 of 125 people (58%) found this review helpful',
#        '28 of 39 people (72%) found this review helpful',
#        '62 of 109 people (57%) found this review helpful',
#        '31 of 38 people (82%) found this review helpful',
#        '21 of 25 people (84%) found this review helpful',
#        '76 of 87 people (87%) found this review helpful',
#        '2 of 20 people (10%) found this review helpful',
#        '33 of 44 people (75%) found this review helpful',
#        '65 of 103 people (63%) found this review helpful',
#        '1,996 of 3,089 people (65%) found this review helpful',
#        '1,056 of 1,494 people (71%) found this review helpful',
#        '324 of 370 people (88%) found this review helpful',
#        '36 of 48 people (75%) found this review helpful',
#        '24 of 26 people (92%) found this review helpful',
#        '26 of 47 people (55%) found this review helpful',
#        '15 of 129 people (12%) found this review helpful',
#        '82 of 125 people (66%) found this review helpful',
#        '25 of 28 people (89%) found this review helpful',
#        '34 of 38 people (89%) found this review helpful',
#        '14 of 70 people (20%) found this review helpful',
#        '2 of 38 people (5%) found this review helpful',
#        '37 of 53 people (70%) found this review helpful',
#        '36 of 54 people (67%) found this review helpful',
#        '76 of 96 people (79%) found this review helpful',
#        '48 of 55 people (87%) found this review helpful',
#        '30 of 37 people (81%) found this review helpful',
#        '9 of 130 people (7%) found this review helpful',
#        '102 of 123 people (83%) found this review helpful',
#        '69 of 101 people (68%) found this review helpful',
#        '21 of 26 people (81%) found this review helpful',
#        '39 of 73 people (53%) found this review helpful',
#        '663 of 810 people (82%) found this review helpful',
#        '23 of 31 people (74%) found this review helpful',
#        '99 of 164 people (60%) found this review helpful',
#        '12 of 29 people (41%) found this review helpful',
#        '20 of 36 people (56%) found this review helpful',
#        '74 of 83 people (89%) found this review helpful',
#        '21 of 30 people (70%) found this review helpful',
#        '115 of 135 people (85%) found this review helpful',
#        '33 of 45 people (73%) found this review helpful',
#        '51 of 59 people (86%) found this review helpful',
#        '5 of 19 people (26%) found this review helpful',
#        '50 of 60 people (83%) found this review helpful',
#        '68 of 88 people (77%) found this review helpful',
#        '27 of 45 people (60%) found this review helpful',
#        '77 of 86 people (90%) found this review helpful',
#        '66 of 92 people (72%) found this review helpful',
#        '91 of 128 people (71%) found this review helpful',
#        '1 of 19 people (5%) found this review helpful',
#        '1 of 25 people (4%) found this review helpful',
#        '787 of 1,040 people (76%) found this review helpful',
#        '23 of 44 people (52%) found this review helpful',
#        '81 of 119 people (68%) found this review helpful',
#        '81 of 133 people (61%) found this review helpful',
#        '114 of 151 people (75%) found this review helpful',
#        '56 of 63 people (89%) found this review helpful',
#        '4 of 37 people (11%) found this review helpful',
#        '535 of 790 people (68%) found this review helpful',
#        '38 of 44 people (86%) found this review helpful',
#        '12 of 28 people (43%) found this review helpful',
#        '21 of 41 people (51%) found this review helpful',
#        '3 of 16 people (19%) found this review helpful',
#        '180 of 252 people (71%) found this review helpful',
#        '1,072 of 1,208 people (89%) found this review helpful',
#        '165 of 196 people (84%) found this review helpful',
#        '192 of 269 people (71%) found this review helpful',
#        '21 of 44 people (48%) found this review helpful',
#        '712 of 830 people (86%) found this review helpful',
#        '12 of 27 people (44%) found this review helpful',
#        '27 of 110 people (25%) found this review helpful',
#        '4 of 21 people (19%) found this review helpful',
#        '46 of 61 people (75%) found this review helpful',
#        '42 of 48 people (88%) found this review helpful',
#        '114 of 160 people (71%) found this review helpful',
#        '42 of 57 people (74%) found this review helpful',
#        '16 of 30 people (53%) found this review helpful',
#        '83 of 105 people (79%) found this review helpful',
#        '22 of 58 people (38%) found this review helpful',
#        '242 of 331 people (73%) found this review helpful',
#        '107 of 138 people (78%) found this review helpful',
#        '12 of 21 people (57%) found this review helpful',
#        '0 of 29 people (0%) found this review helpful',
#        '25 of 33 people (76%) found this review helpful',
#        '16 of 24 people (67%) found this review helpful',
#        '10 of 27 people (37%) found this review helpful',
#        '32 of 44 people (73%) found this review helpful',
#        '13 of 31 people (42%) found this review helpful',
#        '186 of 213 people (87%) found this review helpful',
#        '409 of 578 people (71%) found this review helpful',
#        '0 of 16 people (0%) found this review helpful',
#        '7 of 18 people (39%) found this review helpful',
#        '81 of 151 people (54%) found this review helpful',
#        '145 of 212 people (68%) found this review helpful',
#        '36 of 42 people (86%) found this review helpful',
#        '459 of 561 people (82%) found this review helpful',
#        '127 of 187 people (68%) found this review helpful',
#        '278 of 293 people (95%) found this review helpful',
#        '474 of 588 people (81%) found this review helpful',
#        '24 of 32 people (75%) found this review helpful',
#        '20 of 22 people (91%) found this review helpful',
#        '170 of 200 people (85%) found this review helpful',
#        '1 of 21 people (5%) found this review helpful',
#        '8 of 26 people (31%) found this review helpful',
#        '127 of 151 people (84%) found this review helpful',
#        '2 of 25 people (8%) found this review helpful',
#        '130 of 142 people (92%) found this review helpful',
#        '2 of 49 people (4%) found this review helpful',
#        '40 of 52 people (77%) found this review helpful',
#        '32 of 45 people (71%) found this review helpful',
#        '13 of 23 people (57%) found this review helpful',
#        '9 of 18 people (50%) found this review helpful',
#        '357 of 430 people (83%) found this review helpful',
#        '117 of 161 people (73%) found this review helpful',
#        '1 of 30 people (3%) found this review helpful',
#        '34 of 53 people (64%) found this review helpful',
#        '21 of 34 people (62%) found this review helpful',
#        '64 of 73 people (88%) found this review helpful',
#        '24 of 34 people (71%) found this review helpful',
#        '4 of 19 people (21%) found this review helpful'], dtype=object)

# %% [markdown]
# La proporción de personas que encontraron útil la opinión esta dada sobre cada item, mas no sobre el total de personas que la leyeron, entonces podría resultar útil tomar términos absolutos (quienes encontraron útil la opinión) y descartar términos relativos.

# %%
reviews_desanidado_nona.loc[reviews_desanidado_nona['helpful'].str.contains('No ratings yet', case=False), 'helpful']=reviews_desanidado_nona['helpful'].str.replace('No ratings yet','0', case=False)

# %%
reviews_desanidado_nona.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#    funny                                          helpful recommend  \
# 0      0                                                0      True
# 1      0  15 of 20 people (75%) found this review helpful      True
# 2      0                                                0      True
# 3      0   2 of 2 people (100%) found this review helpful      True
# 4      3  35 of 43 people (81%) found this review helpful      True
#
#                                               review
# 0  Simple yet with great replayability. In my opi...
# 1  I know what you think when you see this title ...
# 2  A suitably punishing roguelike platformer.  Wi...
# 3  This game... is so fun. The fight sequences ha...
# 4                                            Git gud

# %%
reviews_desanidado_nona['helpful']=reviews_desanidado_nona['helpful'].apply(lambda x: x.split(' ')[0])

# %% [markdown]
# Ahora se retiran las comas

# %%
reviews_desanidado_nona['helpful']=reviews_desanidado_nona['helpful'].str.replace(',','')

# %% [markdown]
# Ahora se pasa a tipo entero

# %%
helpful=reviews_desanidado_nona['helpful'].astype(int)

# %%
reviews_desanidado_nona['helpful']=helpful

# %%
reviews_desanidado_nona.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#    funny  helpful recommend                                             review
# 0      0        0      True  Simple yet with great replayability. In my opi...
# 1      0       15      True  I know what you think when you see this title ...
# 2      0        0      True  A suitably punishing roguelike platformer.  Wi...
# 3      0        2      True  This game... is so fun. The fight sequences ha...
# 4      3       35      True                                            Git gud

# %% [markdown]
# La variable recommend se convierte a una variable binaria.

# %%
reviews_desanidado_nona['recommend']=reviews_desanidado_nona['recommend'].astype(int)

# %%
reviews_desanidado_nona.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#    funny  helpful  recommend  \
# 0      0        0          1
# 1      0       15          1
# 2      0        0          1
# 3      0        2          1
# 4      3       35          1
#
#                                               review
# 0  Simple yet with great replayability. In my opi...
# 1  I know what you think when you see this title ...
# 2  A suitably punishing roguelike platformer.  Wi...
# 3  This game... is so fun. The fight sequences ha...
# 4                                            Git gud

# %%
reviews_desanidado_nona=reviews_desanidado_nona.drop(columns=['user_url'])

# %%
reviews_desanidado_nona.head()
# Out:
#              user_id  funny item_id  helpful  recommend  \
# 0  76561197970982479      0    1250        0          1
# 1            js41637      0  251610       15          1
# 2          evcentric      0  248820        0          1
# 3              doctr      0  250320        2          1
# 4          maplemage      3  211420       35          1
#
#                                               review
# 0  Simple yet with great replayability. In my opi...
# 1  I know what you think when you see this title ...
# 2  A suitably punishing roguelike platformer.  Wi...
# 3  This game... is so fun. The fight sequences ha...
# 4                                            Git gud

# %% [markdown]
# Se importa con csv el dataframe

# %%
reviews_desanidado_nona.to_csv('readyfor_sentiment_analysis.csv', index=False)

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

# %% [markdown]
# Se descargan los datos necesarios para VADER

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\57319\AppData\Roaming\nltk_data...
# True

# %% [markdown]
# Inicia el analizador de sentimientos

# %%
sia = SentimentIntensityAnalyzer()

# %%
def sentiment_analysis(text):
    score = sia.polarity_scores(text)['compound']
    if score >= 0.05:
        return 2  
    elif score <= -0.05:
        return 0  
    else:
        return 1

# %%
reviews_desanidado_nona['sentiment_analysis']=reviews_desanidado_nona['review'].apply(sentiment_analysis)

# %%
reviews_desanidado_nona.head()
# Out:
#              user_id  funny item_id  helpful  recommend  \
# 0  76561197970982479      0    1250        0          1
# 1            js41637      0  251610       15          1
# 2          evcentric      0  248820        0          1
# 3              doctr      0  250320        2          1
# 4          maplemage      3  211420       35          1
#
#                                               review  sentiment_analysis
# 0  Simple yet with great replayability. In my opi...                   2
# 1  I know what you think when you see this title ...                   2
# 2  A suitably punishing roguelike platformer.  Wi...                   2
# 3  This game... is so fun. The fight sequences ha...                   2
# 4                                            Git gud                   1

# %%
reviews_desanidado_nona=reviews_desanidado_nona.drop(columns=['review'])

# %%
reviews_desanidado_nona.head()
# Out:
#              user_id  funny item_id  helpful  recommend  sentiment_analysis
# 0  76561197970982479      0    1250        0          1                   2
# 1            js41637      0  251610       15          1                   2
# 2          evcentric      0  248820        0          1                   2
# 3              doctr      0  250320        2          1                   2
# 4          maplemage      3  211420       35          1                   1

# %%
reviews_desanidado_nona.to_csv('readywith_sentiment_analysis.csv', index=False)

# %%
reviews_desanidado_nona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25771 entries, 0 to 25798
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             25771 non-null  object
#  1   funny               25771 non-null  int32
#  2   item_id             25771 non-null  object
#  3   helpful             25771 non-null  int32
#  4   recommend           25771 non-null  int32
#  5   sentiment_analysis  25771 non-null  int64
# dtypes: int32(3), int64(1), object(2)
# memory usage: 2.1+ MB

# %% [markdown]
# Aplicando a la columna objetivo

# %% [markdown]
# OUTPUT_STEAM_GAMES

# %% [markdown]
# Deteccion de codificacion

# %%
archivo1='output_steam_games.json'
detectar_encoding(archivo1)
# Out:
# 'El encoding detectado es ascii con una confianza de 100.000000%'

# %% [markdown]
# Con pandas se puede convertir a dataframe de manera directa

# %%
df_games = pd.read_json('output_steam_games.json', lines=True)
df_games.head(3)
# Out:
#   publisher genres app_name title   url release_date  tags reviews_url specs  \
# 0      None   None     None  None  None         None  None        None  None
# 1      None   None     None  None  None         None  None        None  None
# 2      None   None     None  None  None         None  None        None  None
#
#   price  early_access  id developer
# 0  None           NaN NaN      None
# 1  None           NaN NaN      None
# 2  None           NaN NaN      None

# %%
df_games
# Out:
#               publisher                                 genres  \
# 0                  None                                   None
# 1                  None                                   None
# 2                  None                                   None
# 3                  None                                   None
# 4                  None                                   None
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444             None                                   None
#
#                         app_name                     title  \
# 0                           None                      None
# 1                           None                      None
# 2                           None                      None
# 3                           None                      None
# 4                           None                      None
# ...                          ...                       ...
# 120440            Colony On Mars            Colony On Mars
# 120441  LOGistICAL: South Africa  LOGistICAL: South Africa
# 120442             Russian Roads             Russian Roads
# 120443       EXIT 2 - Directions       EXIT 2 - Directions
# 120444               Maze Run VR                      None
#
#                                                       url release_date  \
# 0                                                    None         None
# 1                                                    None         None
# 2                                                    None         None
# 3                                                    None         None
# 4                                                    None         None
# ...                                                   ...          ...
# 120440  http://store.steampowered.com/app/773640/Colon...   2018-01-04
# 120441  http://store.steampowered.com/app/733530/LOGis...   2018-01-04
# 120442  http://store.steampowered.com/app/610660/Russi...   2018-01-04
# 120443  http://store.steampowered.com/app/658870/EXIT_...   2017-09-02
# 120444  http://store.steampowered.com/app/681550/Maze_...         None
#
#                                                      tags  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 120440              [Strategy, Indie, Casual, Simulation]
# 120441                          [Strategy, Indie, Casual]
# 120442                        [Indie, Simulation, Racing]
# 120443  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...
# 120444  [Early Access, Adventure, Indie, Action, Simul...
#
#                                               reviews_url  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 120440  http://steamcommunity.com/app/773640/reviews/?...
# 120441  http://steamcommunity.com/app/733530/reviews/?...
# 120442  http://steamcommunity.com/app/610660/reviews/?...
# 120443  http://steamcommunity.com/app/658870/reviews/?...
# 120444  http://steamcommunity.com/app/681550/reviews/?...
#
#                                                     specs price  early_access  \
# 0                                                    None  None           NaN
# 1                                                    None  None           NaN
# 2                                                    None  None           NaN
# 3                                                    None  None           NaN
# 4                                                    None  None           NaN
# ...                                                   ...   ...           ...
# 120440                [Single-player, Steam Achievements]  1.99           0.0
# 120441  [Single-player, Steam Achievements, Steam Clou...  4.99           0.0
# 120442  [Single-player, Steam Achievements, Steam Trad...  1.99           0.0
# 120443   [Single-player, Steam Achievements, Steam Cloud]  4.99           0.0
# 120444  [Single-player, Stats, Steam Leaderboards, HTC...  4.99           1.0
#
#               id                 developer
# 0            NaN                      None
# 1            NaN                      None
# 2            NaN                      None
# 3            NaN                      None
# 4            NaN                      None
# ...          ...                       ...
# 120440  773640.0        Nikita "Ghost_RUS"
# 120441  733530.0                    Sacada
# 120442  610660.0  Laush Dmitriy Sergeevich
# 120443  658870.0             xropi,stev3ns
# 120444  681550.0                      None
#
# [120445 rows x 13 columns]

# %% [markdown]
# ahora, facilita el manejo del archivo pasarlo a csv

# %%
df_games.to_csv('output_games.csv', index=False)

# %% [markdown]
# varificacion de clumnas anidadas:

# %%
anidada_True(df_games)
# Out:
# "La/s columna/s con datos anidados es/son: ['genres', 'tags', 'specs']"

# %%
import numpy as np
import gzip
import re
import ast

# %%
df_games.shape
# Out:
# (120445, 13)

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120445 entries, 0 to 120444
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     24083 non-null  object
#  1   genres        28852 non-null  object
#  2   app_name      32133 non-null  object
#  3   title         30085 non-null  object
#  4   url           32135 non-null  object
#  5   release_date  30068 non-null  object
#  6   tags          31972 non-null  object
#  7   reviews_url   32133 non-null  object
#  8   specs         31465 non-null  object
#  9   price         30758 non-null  object
#  10  early_access  32135 non-null  float64
#  11  id            32133 non-null  float64
#  12  developer     28836 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 11.9+ MB

# %%
print(df_games.isna().sum())
# Out:
# publisher       96362
# genres          91593
# app_name        88312
# title           90360
# url             88310
# release_date    90377
# tags            88473
# reviews_url     88312
# specs           88980
# price           89687
# early_access    88310
# id              88312
# developer       91609
# dtype: int64

# %% [markdown]
# Hay una gran cantidad de filas vacias, se procede a eliminar las que esten completamente vacias

# %%
filas_vacias = df_games.isnull().all(axis=1).sum()
print(f"Filas completamente vacías: {filas_vacias} es decir un 73%" )
# Out:
# Filas completamente vacías: 88310 es decir un 73%

# %%
output_games=df_games.dropna(how='all')

# %%
output_games.shape
# Out:
# (32135, 13)

# %%
output_games.isnull().sum()
# Out:
# publisher       8052
# genres          3283
# app_name           2
# title           2050
# url                0
# release_date    2067
# tags             163
# reviews_url        2
# specs            670
# price           1377
# early_access       0
# id                 2
# developer       3299
# dtype: int64

# %% [markdown]
# Se eliminan las columna inecesarias

# %%
output_games.drop(['publisher','url','specs','early_access','reviews_url'],axis=1,inplace=True)
# Out:
# C:\Users\57319\AppData\Local\Temp\ipykernel_6952\529313262.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_games.drop(['publisher','url','specs','early_access','reviews_url'],axis=1,inplace=True)

# %%
output_games.isnull().sum()
# Out:
# genres          3144
# app_name           0
# title           2047
# release_date    2065
# tags               0
# price           1344
# id                 0
# developer       3270
# dtype: int64

# %% [markdown]
# Dado que el juego que no registra nombre, id o tag, no es utili para un sistema de recomendacion, se descatan las filas donde estos datos faltan.

# %%
output_games.dropna(subset=['app_name','tags','id'],inplace=True)
# Out:
# C:\Users\57319\AppData\Local\Temp\ipykernel_6952\784636219.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_games.dropna(subset=['app_name','tags','id'],inplace=True)

# %%
output_games.head()
# Out:
#                                                   genres  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88314                                               None
#
#                       app_name                    title release_date  \
# 88310      Lost Summoner Kitty      Lost Summoner Kitty   2018-01-04
# 88311                Ironbound                Ironbound   2018-01-04
# 88312  Real Pool 3D - Poolians  Real Pool 3D - Poolians   2017-07-24
# 88313                  弹炸人2222                  弹炸人2222   2017-12-07
# 88314            Log Challenge                     None         None
#
#                                                     tags         price  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]          4.99
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...  Free To Play
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...  Free to Play
# 88313                        [Action, Adventure, Casual]          0.99
# 88314                    [Action, Indie, Casual, Sports]          2.99
#
#              id         developer
# 88310  761140.0         Kotoshiro
# 88311  643980.0  Secret Level SRL
# 88312  670290.0      Poolians.com
# 88313  767400.0              彼岸领域
# 88314  773570.0              None

# %%
output_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31970 entries, 88310 to 120444
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   genres        28826 non-null  object
#  1   app_name      31970 non-null  object
#  2   title         29923 non-null  object
#  3   release_date  29905 non-null  object
#  4   tags          31970 non-null  object
#  5   price         30626 non-null  object
#  6   id            31970 non-null  float64
#  7   developer     28700 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 2.2+ MB

# %% [markdown]
# Para el caso especifico del precio, se llenaran los faltantes con el precio promedio

# %%
output_games['price'].unique()
# Out:
# array([4.99, 'Free To Play', 'Free to Play', 0.99, 2.99, 3.99, 9.99,
#        18.99, 29.99, None, 'Free', 10.99, 1.5899999999999999, 14.99, 1.99,
#        59.99, 8.99, 6.99, 7.99, 39.99, 19.99, 7.49, 12.99, 5.99, 2.49,
#        15.99, 1.25, 24.99, 17.99, 61.99, 3.49, 11.99, 13.99, 'Free Demo',
#        'Play for Free!', 34.99, 74.76, 1.49, 32.99, 99.99, 14.95, 69.99,
#        16.99, 79.99, 49.99, 5.0, 44.99, 13.98, 29.96, 109.99, 149.99,
#        771.71, 'Install Now', 21.99, 89.99,
#        'Play WARMACHINE: Tactics Demo', 0.98, 139.92, 4.29, 64.99,
#        'Free Mod', 54.99, 74.99, 'Install Theme', 0.89, 'Third-party',
#        0.5, 'Play Now', 299.99, 1.29, 119.99, 3.0, 15.0, 5.49, 23.99,
#        49.0, 20.99, 10.93, 1.3900000000000001,
#        'Free HITMAN™ Holiday Pack', 36.99, 4.49, 2.0, 4.0, 9.0, 234.99,
#        1.9500000000000002, 1.5, 199.0, 189.0, 6.66, 27.99, 10.49, 129.99,
#        179.0, 26.99, 399.99, 31.99, 399.0, 20.0, 40.0, 3.33, 199.99,
#        22.99, 320.0, 38.85, 71.7, 59.95, 995.0, 27.49, 3.39, 6.0, 19.95,
#        499.99, 16.06, 4.68, 131.4, 44.98, 202.76, 1.0, 2.3,
#        0.9500000000000001, 172.24, 249.99, 2.9699999999999998, 10.96,
#        10.0, 30.0, 2.66, 6.48, 19.29, 11.15, 18.9, 2.89, 'Play the Demo',
#        99.0, 87.94, 599.0, 8.98, 9.69, 0.49, 9.98, 9.95, 7.0,
#        'Starting at $499.00', 'Starting at $449.00', 12.89, 6.49, 1.87,
#        42.99, 41.99, 289.99, 'Free to Try', 23.96, 5.65, 12.0, 13.37,
#        189.96, 124.99, 'Free Movie', 19.98, 160.91, 'Free to Use'],
#       dtype=object)

# %% [markdown]
# Se descartan las demas filas vacias

# %%
output_games.dropna(subset=['genres','release_date','price','developer'],inplace=True)
# Out:
# C:\Users\57319\AppData\Local\Temp\ipykernel_6952\478003002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_games.dropna(subset=['genres','release_date','price','developer'],inplace=True)

# %%
output_games.isnull().sum()
# Out:
# genres          0
# app_name        0
# title           0
# release_date    0
# tags            0
# price           0
# id              0
# developer       0
# dtype: int64

# %%
output_games.head()
# Out:
#                                                   genres  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88315                    [Action, Adventure, Simulation]
#
#                       app_name                    title release_date  \
# 88310      Lost Summoner Kitty      Lost Summoner Kitty   2018-01-04
# 88311                Ironbound                Ironbound   2018-01-04
# 88312  Real Pool 3D - Poolians  Real Pool 3D - Poolians   2017-07-24
# 88313                  弹炸人2222                  弹炸人2222   2017-12-07
# 88315    Battle Royale Trainer    Battle Royale Trainer   2018-01-04
#
#                                                     tags         price  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]          4.99
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...             0
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...  Free to Play
# 88313                        [Action, Adventure, Casual]          0.99
# 88315  [Action, Adventure, Simulation, FPS, Shooter, ...          3.99
#
#              id            developer
# 88310  761140.0            Kotoshiro
# 88311  643980.0     Secret Level SRL
# 88312  670290.0         Poolians.com
# 88313  767400.0                 彼岸领域
# 88315  772540.0  Trickjump Games Ltd

# %% [markdown]
# Se descarta 'title' puesto que es igual a 'app name'

# %%
output_games.drop('title',axis=1,inplace=True)
# Out:
# C:\Users\57319\AppData\Local\Temp\ipykernel_6952\2707288407.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_games.drop('title',axis=1,inplace=True)

# %%
output_games['id'].duplicated().sum()
# Out:
# 1

# %% [markdown]
# Ids duplicados se descartan

# %%
output_games.drop_duplicates(subset='id',inplace=True)
# Out:
# C:\Users\57319\AppData\Local\Temp\ipykernel_6952\646411544.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_games.drop_duplicates(subset='id',inplace=True)

# %%
output_games['id'].duplicated().sum()
# Out:
# 0

# %%
output_games.head(50)
# Out:
#                                                   genres  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88315                    [Action, Adventure, Simulation]
# 88316          [Free to Play, Indie, Simulation, Sports]
# 88317          [Free to Play, Indie, Simulation, Sports]
# 88318          [Free to Play, Indie, Simulation, Sports]
# 88322            [Action, Adventure, Casual, Indie, RPG]
# 88323                                    [Casual, Indie]
# 88324                        [Casual, Indie, Simulation]
# 88325   [Adventure, Casual, Indie, Simulation, Strategy]
# 88326          [Free to Play, Indie, Simulation, Sports]
# 88327   [Adventure, Casual, Indie, Simulation, Strategy]
# 88328          [Free to Play, Indie, Simulation, Sports]
# 88331                         [Action, Adventure, Indie]
# 88333                       [Racing, Simulation, Sports]
# 88334                       [Racing, Simulation, Sports]
# 88335                                    [Action, Indie]
# 88337                            [Action, Indie, Racing]
# 88338                                           [Action]
# 88339                               [Action, Indie, RPG]
# 88343                        [Casual, Indie, Simulation]
# 88347                           [Action, Adventure, RPG]
# 88348                    [Adventure, Casual, Indie, RPG]
# 88349                                         [Strategy]
# 88350                                         [Strategy]
# 88351                               [Action, Indie, RPG]
# 88356            [Action, Indie, Strategy, Early Access]
# 88358                    [Action, Adventure, Indie, RPG]
# 88359                   [Casual, Strategy, Early Access]
# 88360                                    [Action, Indie]
# 88362                        [Action, Adventure, Casual]
# 88364           [Adventure, Casual, Free to Play, Indie]
# 88365                                           [Action]
# 88366                                  [Indie, Strategy]
# 88367                               [Action, Indie, RPG]
# 88368                                [Indie, Simulation]
# 88369                                           [Racing]
# 88370                                    [Casual, Indie]
# 88371                                    [Casual, Indie]
# 88372                                         [Strategy]
# 88373                                         [Strategy]
# 88374                                   [Adventure, RPG]
# 88375                                           [Racing]
# 88376                                           [Racing]
# 88377                                [Action, Adventure]
# 88378                                         [Strategy]
# 88379                                              [RPG]
# 88380                           [Action, Adventure, RPG]
#
#                                                 app_name release_date  \
# 88310                                Lost Summoner Kitty   2018-01-04
# 88311                                          Ironbound   2018-01-04
# 88312                            Real Pool 3D - Poolians   2017-07-24
# 88313                                            弹炸人2222   2017-12-07
# 88315                              Battle Royale Trainer   2018-01-04
# 88316                       SNOW - All Access Basic Pass   2018-01-04
# 88317                         SNOW - All Access Pro Pass   2018-01-04
# 88318                      SNOW - All Access Legend Pass   2018-01-04
# 88322  Army of Tentacles: (Not) A Cthulhu Dating Sim:...   2018-01-04
# 88323                                        Beach Rules   2018-01-04
# 88324                        Planetarium 2 - Zen Odyssey   2018-01-03
# 88325                            The first thrust of God   2018-01-03
# 88326                                SNOW - Starter Pack   2018-01-03
# 88327            The first thrust of God - All Aircrafts   2018-01-03
# 88328                               SNOW - Lifetime Pack   2018-01-03
# 88331                           The Warrior Of Treasures   2018-01-03
# 88333                       RC Plane 3 - Canyon Scenario   2017-12-22
# 88334                                 RC Plane 3 - F-53B   2017-12-23
# 88335                                        DinoBlaster   2018-01-03
# 88337                               Carmageddon Max Pack   1997-06-30
# 88338                                          Half-Life   1998-11-08
# 88339                                        Fallen Mage   2016-11-25
# 88343                                Vaporwave Simulator   2018-01-01
# 88347                             Underdone - Soundtrack   2018-01-01
# 88348                                    Bitcoin Clicker   2018-01-01
# 88349                     Disciples II: Gallean's Return   2006-07-06
# 88350                    Disciples II: Rise of the Elves   2006-07-06
# 88351                             The Ship: Murder Party   2006-07-11
# 88356                                            Souland   2017-12-29
# 88358                                   TAROTICA VOO DOO   2017-12-29
# 88359                              Chronicles of Vinland   2017-12-29
# 88360                                         Orbitality   2017-12-29
# 88362                             Atomic Adam: Episode 1   2017-12-30
# 88364            Mirt. Tales of the Cold Land. Chapter 2   2017-12-29
# 88365                                      Advent Rising   2005-08-09
# 88366                                             DEFCON   2006-09-29
# 88367                            The Ship: Single Player   2006-11-20
# 88368                                        Garry's Mod   2006-11-29
# 88369                               RACE - The WTCC Game   2006-11-24
# 88370                                      Zen of Sudoku   2006-12-14
# 88371                         Gumboy - Crazy Adventures™   2006-12-19
# 88372                                      Ghost Master®   2003-08-23
# 88373                                Vegas: Make It Big™   2006-12-21
# 88374                     Dreamfall: The Longest Journey   2006-04-17
# 88375                                         FlatOut 2™   2006-08-01
# 88376                                            FlatOut   2005-07-12
# 88377                    Lost Planet™: Extreme Condition   2007-06-26
# 88378                                      CivCity: Rome   2006-07-24
# 88379                                        Arx Fatalis   2002-11-12
# 88380                                The Longest Journey   2000-11-17
#
#                                                     tags         price  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]          4.99
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...             0
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...  Free to Play
# 88313                        [Action, Adventure, Casual]          0.99
# 88315  [Action, Adventure, Simulation, FPS, Shooter, ...          3.99
# 88316          [Free to Play, Indie, Simulation, Sports]          9.99
# 88317          [Free to Play, Indie, Simulation, Sports]         18.99
# 88318          [Free to Play, Indie, Simulation, Sports]         29.99
# 88322            [Action, Adventure, RPG, Indie, Casual]         10.99
# 88323          [Casual, Indie, Pixel Graphics, Cute, 2D]          3.99
# 88324                        [Indie, Casual, Simulation]          2.99
# 88325  [Strategy, Adventure, Indie, Casual, Simulatio...          1.59
# 88326          [Free to Play, Indie, Simulation, Sports]         14.99
# 88327  [Strategy, Adventure, Indie, Casual, Simulatio...          1.99
# 88328          [Free to Play, Indie, Simulation, Sports]         59.99
# 88331                         [Action, Adventure, Indie]          0.99
# 88333                       [Simulation, Racing, Sports]          2.99
# 88334                       [Simulation, Racing, Sports]          2.99
# 88335                                    [Indie, Action]          4.99
# 88337  [Racing, Action, Classic, Indie, Gore, 1990's,...          9.99
# 88338  [FPS, Classic, Action, Sci-fi, Singleplayer, S...          9.99
# 88339                               [Action, RPG, Indie]          1.99
# 88343                        [Casual, Indie, Simulation]          0.99
# 88347                           [Action, Adventure, RPG]          8.99
# 88348           [Adventure, RPG, Indie, Casual, Clicker]          0.99
# 88349  [Turn-Based Strategy, Strategy, Classic, Atmos...          6.99
# 88350  [Strategy, Turn-Based Strategy, Fantasy, Turn-...          6.99
# 88351  [Multiplayer, Indie, Action, First-Person, Ste...          9.99
# 88356  [Early Access, Strategy, Action, Indie, Pixel ...          7.99
# 88358                    [Indie, Action, Adventure, RPG]         10.99
# 88359  [Early Access, Casual, Strategy, City Builder,...          9.99
# 88360                                    [Indie, Action]          9.99
# 88362                        [Action, Adventure, Casual]          1.99
# 88364           [Adventure, Indie, Casual, Free to Play]          0.99
# 88365  [Action, Sci-fi, Story Rich, Singleplayer, Thi...          9.99
# 88366  [Strategy, Indie, Multiplayer, Wargame, Cold W...          9.99
# 88367            [Action, RPG, Indie, Singleplayer, FPS]          9.99
# 88368  [Sandbox, Multiplayer, Funny, Moddable, Buildi...          9.99
# 88369                               [Racing, Simulation]         39.99
# 88370                            [Casual, Indie, Puzzle]          Free
# 88371                      [Casual, Indie, Singleplayer]          4.99
# 88372  [Strategy, Comedy, Puzzle, Simulation, Classic...          4.99
# 88373                 [Strategy, Simulation, Management]          4.99
# 88374  [Adventure, Female Protagonist, Story Rich, Fa...         19.99
# 88375  [Racing, Destruction, Multiplayer, Great Sound...          9.99
# 88376  [Racing, Destruction, Driving, Multiplayer, Cl...          7.49
# 88377  [Action, Adventure, Third-Person Shooter, Mech...         14.99
# 88378         [Strategy, City Builder, Simulation, Rome]          9.99
# 88379  [RPG, First-Person, Classic, Atmospheric, Fant...          4.99
# 88380  [Adventure, Point & Click, Female Protagonist,...          9.99
#
#              id                       developer
# 88310  761140.0                       Kotoshiro
# 88311  643980.0                Secret Level SRL
# 88312  670290.0                    Poolians.com
# 88313  767400.0                            彼岸领域
# 88315  772540.0             Trickjump Games Ltd
# 88316  774276.0          Poppermost Productions
# 88317  774277.0          Poppermost Productions
# 88318  774278.0          Poppermost Productions
# 88322  770380.0  Stegalosaurus Game Development
# 88323  768880.0               Copperpick Studio
# 88324  765320.0                    Ghulam Jewel
# 88325  773650.0                          Apillo
# 88326  774271.0          Poppermost Productions
# 88327  773690.0                          Apillo
# 88328  774279.0          Poppermost Productions
# 88331  768060.0                     Tero Lunkka
# 88333  775880.0                    FrozenPepper
# 88334  775881.0                    FrozenPepper
# 88335  653960.0                   Casey Labrack
# 88337  282010.0             Stainless Games Ltd
# 88338      70.0                           Valve
# 88339  752360.0                        dev4play
# 88343  766850.0                        ETGgames
# 88347  754360.0                   The Commander
# 88348  716110.0             lalalaZero,Urbanoff
# 88349    1640.0                  Strategy First
# 88350    1630.0                  Strategy First
# 88351    2400.0                 Outerlight Ltd.
# 88356  759920.0                        Ultraint
# 88358  603280.0               TPM.CO SOFT WORKS
# 88359  753110.0                 Wonderbox Games
# 88360  753100.0                 Wonderbox Games
# 88362  764280.0               Mad Unicorn Games
# 88364  758550.0                  Emanon Studios
# 88365    3800.0                    GlyphX Games
# 88366    1520.0           Introversion Software
# 88367    2420.0                 Outerlight Ltd.
# 88368    4000.0               Facepunch Studios
# 88369    4230.0                          SimBin
# 88370    4900.0    Unknown Worlds Entertainment
# 88371    2520.0                 CINEMAX, s.r.o.
# 88372    6200.0                    Sick Puppies
# 88373    6210.0                         Deepred
# 88374    6300.0                          Funcom
# 88375    2990.0           Bugbear Entertainment
# 88376    6220.0           Bugbear Entertainment
# 88377    6510.0                CAPCOM Co., Ltd.
# 88378    3980.0   FireFly Studios,Firaxis Games
# 88379    1700.0                  Arkane Studios
# 88380    6310.0                          Funcom

# %%
output_games['release_date'].unique()
# Out:
# array(['2018-01-04', '2017-07-24', '2017-12-07', ..., '2003-11-01',
#        '2004-03-16', '2004-03-01'], dtype=object)

# %%
valores = ['SOON', 'SOON™','coming soon']

# %%
output_games = output_games[~output_games['release_date'].isin(valores)]

# %% [markdown]
# Se toma el año de la columna 'release data'

# %%
output_games['release_anio'] = output_games['release_date'].apply(lambda x: x.split('-')[0])

# %% [markdown]
# Se elimina la fecha depues de tomar solo el año

# %%
output_games.drop('release_date',axis=1,inplace=True)

# %%
output_games.head()
# Out:
#                                                   genres  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88315                    [Action, Adventure, Simulation]
#
#                       app_name  \
# 88310      Lost Summoner Kitty
# 88311                Ironbound
# 88312  Real Pool 3D - Poolians
# 88313                  弹炸人2222
# 88315    Battle Royale Trainer
#
#                                                     tags         price  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]          4.99
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...             0
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...  Free to Play
# 88313                        [Action, Adventure, Casual]          0.99
# 88315  [Action, Adventure, Simulation, FPS, Shooter, ...          3.99
#
#              id            developer release_anio
# 88310  761140.0            Kotoshiro         2018
# 88311  643980.0     Secret Level SRL         2018
# 88312  670290.0         Poolians.com         2017
# 88313  767400.0                 彼岸领域         2017
# 88315  772540.0  Trickjump Games Ltd         2018

# %% [markdown]
# Se modifica la columna price para que no hayan caracteres alfabeticos

# %%
output_games['price'] =output_games['price'].apply(lambda x: 0 if isinstance(x, str) else x)

# %%
output_games['price'].unique()
# Out:
# array([4.9900e+00, 0.0000e+00, 9.9000e-01, 3.9900e+00, 9.9900e+00,
#        1.8990e+01, 2.9990e+01, 1.0990e+01, 2.9900e+00, 1.5900e+00,
#        1.4990e+01, 1.9900e+00, 5.9990e+01, 8.9900e+00, 6.9900e+00,
#        7.9900e+00, 3.9990e+01, 1.9990e+01, 7.4900e+00, 1.2990e+01,
#        5.9900e+00, 2.4900e+00, 1.5990e+01, 1.2500e+00, 2.4990e+01,
#        1.7990e+01, 6.1990e+01, 3.4900e+00, 1.1990e+01, 1.3990e+01,
#        3.4990e+01, 1.4900e+00, 3.2990e+01, 9.9990e+01, 1.4950e+01,
#        6.9990e+01, 1.6990e+01, 7.9990e+01, 4.9990e+01, 5.0000e+00,
#        1.3980e+01, 2.9960e+01, 1.0999e+02, 1.4999e+02, 7.7171e+02,
#        2.1990e+01, 8.9990e+01, 9.8000e-01, 1.3992e+02, 4.2900e+00,
#        5.4990e+01, 6.4990e+01, 7.4990e+01, 8.9000e-01, 5.0000e-01,
#        2.9999e+02, 1.2900e+00, 1.1999e+02, 4.4990e+01, 3.0000e+00,
#        1.5000e+01, 5.4900e+00, 2.3990e+01, 4.9000e+01, 1.0930e+01,
#        1.3900e+00, 3.6990e+01, 4.4900e+00, 2.0000e+00, 4.0000e+00,
#        1.9500e+00, 1.5000e+00, 1.9900e+02, 1.8900e+02, 6.6600e+00,
#        2.7990e+01, 1.2999e+02, 1.7900e+02, 2.6990e+01, 3.9999e+02,
#        3.1990e+01, 3.9900e+02, 2.0000e+01, 4.0000e+01, 3.3300e+00,
#        2.2990e+01, 3.2000e+02, 3.8850e+01, 7.1700e+01, 9.9500e+02,
#        2.7490e+01, 3.3900e+00, 6.0000e+00, 1.9950e+01, 2.0990e+01,
#        4.9999e+02, 1.9999e+02, 1.6060e+01, 4.6800e+00, 1.3140e+02,
#        4.4980e+01, 2.0276e+02, 2.3000e+00, 9.5000e-01, 1.7224e+02,
#        2.4999e+02, 2.9700e+00, 1.0960e+01, 1.0000e+01, 3.0000e+01,
#        2.6600e+00, 6.4800e+00, 1.0000e+00, 1.1150e+01, 9.9000e+01,
#        8.7940e+01, 4.9000e-01, 9.9800e+00, 9.9500e+00, 7.0000e+00,
#        1.2890e+01, 6.4900e+00, 1.8700e+00, 4.2990e+01, 4.1990e+01,
#        2.8999e+02, 2.3960e+01, 5.6500e+00, 1.2000e+01, 5.9950e+01,
#        1.3370e+01, 1.8996e+02, 1.2499e+02, 1.9980e+01, 1.6091e+02])

# %%
output_games.head()
# Out:
#                                                   genres  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88315                    [Action, Adventure, Simulation]
#
#                       app_name  \
# 88310      Lost Summoner Kitty
# 88311                Ironbound
# 88312  Real Pool 3D - Poolians
# 88313                  弹炸人2222
# 88315    Battle Royale Trainer
#
#                                                     tags  price        id  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]   4.99  761140.0
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...   0.00  643980.0
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...   0.00  670290.0
# 88313                        [Action, Adventure, Casual]   0.99  767400.0
# 88315  [Action, Adventure, Simulation, FPS, Shooter, ...   3.99  772540.0
#
#                  developer release_anio
# 88310            Kotoshiro         2018
# 88311     Secret Level SRL         2018
# 88312         Poolians.com         2017
# 88313                 彼岸领域         2017
# 88315  Trickjump Games Ltd         2018

# %% [markdown]
# Se normanliza app_name y developer pcon la funcion title()

# %%
output_games['app_name']=output_games['app_name'].apply(lambda x: x.title())

# %%
output_games['developer']=output_games['developer'].apply(lambda x: x.title())

# %%
output_games[['id', 'price']] = output_games[['id', 'price']].astype({'id': 'int32', 'price': 'float16'})

# %%
output_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27445 entries, 88310 to 120443
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   genres        27445 non-null  object
#  1   app_name      27445 non-null  object
#  2   tags          27445 non-null  object
#  3   price         27445 non-null  float16
#  4   id            27445 non-null  int32
#  5   developer     27445 non-null  object
#  6   release_anio  27445 non-null  object
# dtypes: float16(1), int32(1), object(5)
# memory usage: 1.4+ MB

# %%
output_games.to_csv('output_games_clean.csv', index=False)

# %% [markdown]
# AUTRALIAN_USERS_ITEMS

# %%
import gzip
import json
import ast

# %%
import pandas as pd

# %% [markdown]
# Comprimiendo el archivo json.

# %%
with open('australian_users_items.json', 'rb') as f_in:
    with gzip.open('australian_users_items.json.gz', 'rt') as f_out:
        f_out.write(f_in.read())

# %% [markdown]
# Debido alimitaciones de memoria la base de datos, se crea un codigo que omita las lineas con error

# %%
data1 = []

with gzip.open(r"C:\Users\57319\Desktop\Henry\Proyecto_Individual\australian_users_items.json.gz", 'rt', encoding='utf-8') as file:
    for line in file:
        try:
            json_data = ast.literal_eval(line)
            data1.append(json_data)
        except ValueError as e:
            print(f"Error en la línea: {line}")
            continue

# %%
df_items = pd.DataFrame(data1)

# %%
df_items.head()
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1            js41637          888  76561198035864385
# 2          evcentric          137  76561198007712555
# 3         Riot-Punch          328  76561197963445855
# 4              doctr          541  76561198002099482
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
# 2             http://steamcommunity.com/id/evcentric
# 3            http://steamcommunity.com/id/Riot-Punch
# 4                 http://steamcommunity.com/id/doctr
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2  [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4  [{'item_id': '300', 'item_name': 'Day of Defea...

# %% [markdown]
# Se guarda el dataframe en un csv

# %%
df_items.to_csv('items.csv', index=False)

# %%
df_items=pd.read_csv('items.csv')

# %%
df_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88310 entries, 0 to 88309
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      88310 non-null  object
#  1   items_count  88310 non-null  int64
#  2   steam_id     88310 non-null  object
#  3   user_url     88310 non-null  object
#  4   items        88310 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.4+ MB

# %%
anidada_True(df_items)
# Out:
# "La/s columna/s con datos anidados es/son: ['items']"

# %%
df_items.shape
# Out:
# (88310, 5)

# %%
df_items.head()
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1            js41637          888  76561198035864385
# 2          evcentric          137  76561198007712555
# 3         Riot-Punch          328  76561197963445855
# 4              doctr          541  76561198002099482
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
# 2             http://steamcommunity.com/id/evcentric
# 3            http://steamcommunity.com/id/Riot-Punch
# 4                 http://steamcommunity.com/id/doctr
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2  [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4  [{'item_id': '300', 'item_name': 'Day of Defea...

# %% [markdown]
# Se eliminana dos columnas descartables.

# %%
df_items.drop(['steam_id','user_url'],axis=1,inplace=True)

# %% [markdown]
# Ahora de desanida la columna items.

# %%
df_expand=df_items.explode('items')

# %%
df_expand.head()
# Out:
#              user_id  items_count  \
# 0  76561197970982479          277
# 0  76561197970982479          277
# 0  76561197970982479          277
# 0  76561197970982479          277
# 0  76561197970982479          277
#
#                                                items
# 0  {'item_id': '10', 'item_name': 'Counter-Strike...
# 0  {'item_id': '20', 'item_name': 'Team Fortress ...
# 0  {'item_id': '30', 'item_name': 'Day of Defeat'...
# 0  {'item_id': '40', 'item_name': 'Deathmatch Cla...
# 0  {'item_id': '50', 'item_name': 'Half-Life: Opp...

# %%
df_expand.to_csv('items_dict.csv', index=False)

# %%
df_descompuesto=pd.json_normalize(df_expand['items'])

# %%
df_descompuesto.drop(['item_name','playtime_2weeks'],axis=1,inplace=True)

# %%
df_final=pd.concat([df_expand.reset_index(drop=True), df_descompuesto.reset_index(drop=True)], axis=1)

# %%
df_users1=df_final.drop('items', axis=1)

# %%
df_users1.to_csv('items_final.csv', index=False)

# %%
df_users1.head()
# Out:
#              user_id  items_count item_id  playtime_forever
# 0  76561197970982479          277      10               6.0
# 1  76561197970982479          277      20               0.0
# 2  76561197970982479          277      30               7.0
# 3  76561197970982479          277      40               0.0
# 4  76561197970982479          277      50               0.0

# %%
df_users1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5170015 entries, 0 to 5170014
# Data columns (total 4 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_id           object
#  1   items_count       int64
#  2   item_id           object
#  3   playtime_forever  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 157.8+ MB

# %%
df_users1.isnull().sum()
# Out:
# user_id                 0
# items_count             0
# item_id             16806
# playtime_forever    16806
# dtype: int64

# %% [markdown]
# Se descartan los items sin id de juego

# %%
df_users1.dropna(subset='item_id',inplace=True)

# %%
df_users1.isnull().sum()
# Out:
# user_id             0
# items_count         0
# item_id             0
# playtime_forever    0
# dtype: int64

# %%
df_users1=df_users1.astype({'item_id':'int32','playtime_forever':'float16', 'items_count':'int16'})
# Out:
# C:\Users\57319\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\dtypes\astype.py:133: RuntimeWarning: overflow encountered in cast
#   return arr.astype(dtype, copy=True)

# %%
df_users1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5153209 entries, 0 to 5170013
# Data columns (total 4 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_id           object
#  1   items_count       int16
#  2   item_id           int32
#  3   playtime_forever  float16
# dtypes: float16(1), int16(1), int32(1), object(1)
# memory usage: 117.9+ MB

# %%
df_users1.to_csv('items_ready.csv', index=False)

# %% [markdown]
# Pasando los archivos definitivos a parket

# %%
reviews_ready=pd.read_csv('readywith_sentiment_analysis.csv')

# %%
games_ready=pd.read_csv('output_games_clean.csv')

# %%
users_ready=pd.read_csv('items_ready.csv')

# %%
reviews_ready.to_parquet(r'reviews.parquet', index= False)

# %%
games_ready.to_parquet(r'games.parquet', index=False)

# %%
users_ready.to_parquet(r'users.parquet', index=False)
